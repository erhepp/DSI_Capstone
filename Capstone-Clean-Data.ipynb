# %% [markdown]
# ## Work with a sample JSON for quake data in WA and OR
#
# Learn how to work with the USGS ComCat formats

# %%
import json
import pandas as pd
from pprint import pprint

# %%
with open("WA-OR-catalog.json") as json_file:
    json_data = json.load(json_file)

# %%
type(json_data)
# Out:
# dict

# %%
json_data
# Out:
# {u'bbox': [-126.8669, 42.3306, 3.64, -118.5953333, 48.7741667, 56.45],
#  u'features': [{u'geometry': {u'coordinates': [-122.6071667,
#      48.7741667,
#      16.27],
#     u'type': u'Point'},
#    u'id': u'uw61297016',
#    u'properties': {u'alert': None,
#     u'cdi': 3.8,
#     u'code': u'61297016',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61297016&format=geojson',
#     u'dmin': 0.1771,
#     u'felt': 286,
#     u'gap': 99,
#     u'ids': u',uw61297016,us1000955h,',
#     u'mag': 3.1,
#     u'magType': u'ml',
#     u'mmi': 2.9,
#     u'net': u'uw',
#     u'nst': 31,
#     u'place': u'4km S of Marietta, Washington',
#     u'rms': 0.21,
#     u'sig': 257,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1498725603370,
#     u'title': u'M 3.1 - 4km S of Marietta, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1500447547040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61297016'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.6675, 48.2565, 8.47],
#     u'type': u'Point'},
#    u'id': u'uw61276967',
#    u'properties': {u'alert': None,
#     u'cdi': 3.8,
#     u'code': u'61276967',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61276967&format=geojson',
#     u'dmin': 0.1843,
#     u'felt': 31,
#     u'gap': 74,
#     u'ids': u',uw61276967,us20009pki,',
#     u'mag': 2.92,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 24,
#     u'place': u'4km W of Darrington, Washington',
#     u'rms': 0.32,
#     u'sig': 143,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1498361114610,
#     u'title': u'M 2.9 - 4km W of Darrington, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1501131675040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61276967'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.8856667, 47.8403333, 56.45],
#     u'type': u'Point'},
#    u'id': u'uw61293181',
#    u'properties': {u'alert': None,
#     u'cdi': 3.8,
#     u'code': u'61293181',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61293181&format=geojson',
#     u'dmin': 0.03217,
#     u'felt': 156,
#     u'gap': 31,
#     u'ids': u',us20009mws,uw61293181,',
#     u'mag': 3.69,
#     u'magType': u'ml',
#     u'mmi': 2.58,
#     u'net': u'uw',
#     u'nst': 62,
#     u'place': u'17km WSW of Port Ludlow, Washington',
#     u'rms': 0.15,
#     u'sig': 269,
#     u'sources': u',us,uw,',
#     u'status': u'reviewed',
#     u'time': 1497585325800,
#     u'title': u'M 3.7 - 17km WSW of Port Ludlow, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,moment-tensor,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1500163839749,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61293181'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.0955, 45.0576667, 22.48],
#     u'type': u'Point'},
#    u'id': u'uw61272097',
#    u'properties': {u'alert': None,
#     u'cdi': 4.1,
#     u'code': u'61272097',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61272097&format=geojson',
#     u'dmin': 0.1947,
#     u'felt': 118,
#     u'gap': 60,
#     u'ids': u',uw61272097,us10008x4t,',
#     u'mag': 2.96,
#     u'magType': u'ml',
#     u'mmi': 2.65,
#     u'net': u'uw',
#     u'nst': 32,
#     u'place': u'9km NW of Keizer, Oregon',
#     u'rms': 0.22,
#     u'sig': 183,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1496332977740,
#     u'title': u'M 3.0 - 9km NW of Keizer, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1498847650040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61272097'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.5818333, 47.5815, 24.03],
#     u'type': u'Point'},
#    u'id': u'uw61268327',
#    u'properties': {u'alert': None,
#     u'cdi': 3.4,
#     u'code': u'61268327',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61268327&format=geojson',
#     u'dmin': 0.009269,
#     u'felt': 18,
#     u'gap': 37,
#     u'ids': u',uw61268327,us10008u20,',
#     u'mag': 2.77,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 43,
#     u'place': u'1km ESE of Enetai, Washington',
#     u'rms': 0.24,
#     u'sig': 124,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1495399431280,
#     u'title': u'M 2.8 - 1km ESE of Enetai, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1498314661040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61268327'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.5891667, 47.5931667, 25.11],
#     u'type': u'Point'},
#    u'id': u'uw61267487',
#    u'properties': {u'alert': None,
#     u'cdi': 2.7,
#     u'code': u'61267487',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61267487&format=geojson',
#     u'dmin': 0.01626,
#     u'felt': 8,
#     u'gap': 36,
#     u'ids': u',uw61267487,us10008tdr,',
#     u'mag': 2.5,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 33,
#     u'place': u'1km NE of Enetai, Washington',
#     u'rms': 0.32,
#     u'sig': 98,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1495131332560,
#     u'title': u'M 2.5 - 1km NE of Enetai, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1497540178040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61267487'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.4663333, 47.9616667, 23.67],
#     u'type': u'Point'},
#    u'id': u'uw61265222',
#    u'properties': {u'alert': None,
#     u'cdi': 4.1,
#     u'code': u'61265222',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61265222&format=geojson',
#     u'dmin': 0.06328,
#     u'felt': 594,
#     u'gap': 55,
#     u'ids': u',uw61265222,us10008rit,',
#     u'mag': 3.43,
#     u'magType': u'ml',
#     u'mmi': 2.9,
#     u'net': u'uw',
#     u'nst': 39,
#     u'place': u'6km SE of Freeland, Washington',
#     u'rms': 0.19,
#     u'sig': 425,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1494525395950,
#     u'title': u'M 3.4 - 6km SE of Freeland, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1496027875574,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61265222'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.5646667, 47.5896667, 21.55],
#     u'type': u'Point'},
#    u'id': u'uw61265082',
#    u'properties': {u'alert': None,
#     u'cdi': 3.4,
#     u'code': u'61265082',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61265082&format=geojson',
#     u'dmin': 0.02563,
#     u'felt': 31,
#     u'gap': 37,
#     u'ids': u',uw61265082,us10008rgc,',
#     u'mag': 2.6,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 41,
#     u'place': u'2km ENE of Enetai, Washington',
#     u'rms': 0.15,
#     u'sig': 115,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1494495396720,
#     u'title': u'M 2.6 - 2km ENE of Enetai, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1497340038040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61265082'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.5841667, 47.5886667, 24.06],
#     u'type': u'Point'},
#    u'id': u'uw61265017',
#    u'properties': {u'alert': None,
#     u'cdi': 4.5,
#     u'code': u'61265017',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61265017&format=geojson',
#     u'dmin': 0.03728,
#     u'felt': 946,
#     u'gap': 37,
#     u'ids': u',us10008rey,uw61265017,',
#     u'mag': 3.47,
#     u'magType': u'ml',
#     u'mmi': 3.03,
#     u'net': u'uw',
#     u'nst': 60,
#     u'place': u'1km ENE of Enetai, Washington',
#     u'rms': 0.2,
#     u'sig': 611,
#     u'sources': u',us,uw,',
#     u'status': u'reviewed',
#     u'time': 1494488124720,
#     u'title': u'M 3.5 - 1km ENE of Enetai, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1496219077040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61265017'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.584, 47.5791667, 24.5],
#     u'type': u'Point'},
#    u'id': u'uw61264612',
#    u'properties': {u'alert': None,
#     u'cdi': 3.6,
#     u'code': u'61264612',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61264612&format=geojson',
#     u'dmin': 0.0366,
#     u'felt': 795,
#     u'gap': 37,
#     u'ids': u',uw61264612,us10008r2n,',
#     u'mag': 3.38,
#     u'magType': u'ml',
#     u'mmi': 2.94,
#     u'net': u'uw',
#     u'nst': 57,
#     u'place': u'1km ESE of Enetai, Washington',
#     u'rms': 0.21,
#     u'sig': 462,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1494404072090,
#     u'title': u'M 3.4 - 1km ESE of Enetai, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1497337558040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61264612'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.5995, 47.5693333, 26.51],
#     u'type': u'Point'},
#    u'id': u'uw61277931',
#    u'properties': {u'alert': None,
#     u'cdi': 3.4,
#     u'code': u'61277931',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61277931&format=geojson',
#     u'dmin': 0.02666,
#     u'felt': 229,
#     u'gap': 41,
#     u'ids': u',uw61277931,us10008nz4,',
#     u'mag': 3.31,
#     u'magType': u'ml',
#     u'mmi': 2.77,
#     u'net': u'uw',
#     u'nst': 27,
#     u'place': u'1km S of Enetai, Washington',
#     u'rms': 0.16,
#     u'sig': 246,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1493839236470,
#     u'title': u'M 3.3 - 1km S of Enetai, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1501298178040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61277931'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.7573333, 48.1763333, 23.26],
#     u'type': u'Point'},
#    u'id': u'uw61272661',
#    u'properties': {u'alert': None,
#     u'cdi': 4.1,
#     u'code': u'61272661',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61272661&format=geojson',
#     u'dmin': 0.1402,
#     u'felt': 172,
#     u'gap': 36,
#     u'ids': u',uw61272661,us10008j6a,',
#     u'mag': 3.01,
#     u'magType': u'ml',
#     u'mmi': 2.52,
#     u'net': u'uw',
#     u'nst': 36,
#     u'place': u'7km N of Port Townsend, Washington',
#     u'rms': 0.25,
#     u'sig': 210,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1492664823640,
#     u'title': u'M 3.0 - 7km N of Port Townsend, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1499737718040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61272661'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-124.6165, 44.4392, 36.68],
#     u'type': u'Point'},
#    u'id': u'us10008hyg',
#    u'properties': {u'alert': None,
#     u'cdi': 1,
#     u'code': u'10008hyg',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us10008hyg&format=geojson',
#     u'dmin': 0.393,
#     u'felt': 0,
#     u'gap': 140,
#     u'ids': u',us10008hyg,uw61271261,',
#     u'mag': 2.7,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'43km W of Waldport, Oregon',
#     u'rms': 0.86,
#     u'sig': 112,
#     u'sources': u',us,uw,',
#     u'status': u'reviewed',
#     u'time': 1492283203970,
#     u'title': u'M 2.7 - 43km W of Waldport, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1499278201040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/us10008hyg'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-124.6193, 44.4357, 37.67],
#     u'type': u'Point'},
#    u'id': u'us10008hwk',
#    u'properties': {u'alert': None,
#     u'cdi': 3.8,
#     u'code': u'10008hwk',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us10008hwk&format=geojson',
#     u'dmin': 0.394,
#     u'felt': 26,
#     u'gap': 130,
#     u'ids': u',us10008hwk,uw61271121,',
#     u'mag': 3.9,
#     u'magType': u'mb',
#     u'mmi': 3.16,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'43km W of Waldport, Oregon',
#     u'rms': 1.18,
#     u'sig': 244,
#     u'sources': u',us,uw,',
#     u'status': u'reviewed',
#     u'time': 1492267715220,
#     u'title': u'M 3.9 - 43km W of Waldport, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1499278201040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/us10008hwk'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-126.8669, 43.4224, 10], u'type': u'Point'},
#    u'id': u'us10008guf',
#    u'properties': {u'alert': None,
#     u'cdi': 2.7,
#     u'code': u'10008guf',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us10008guf&format=geojson',
#     u'dmin': 2.073,
#     u'felt': 4,
#     u'gap': 181,
#     u'ids': u',us10008guf,',
#     u'mag': 4.2,
#     u'magType': u'mb',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'202km W of Bandon, Oregon',
#     u'rms': 0.9,
#     u'sig': 272,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 1491961505820,
#     u'title': u'M 4.2 - 202km W of Bandon, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1499278197040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/us10008guf'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.332, 46.4483333, 11.75],
#     u'type': u'Point'},
#    u'id': u'uw61257321',
#    u'properties': {u'alert': None,
#     u'cdi': 4.3,
#     u'code': u'61257321',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61257321&format=geojson',
#     u'dmin': 0.1524,
#     u'felt': 34,
#     u'gap': 70,
#     u'ids': u',uw61257321,us20008s7h,',
#     u'mag': 3.21,
#     u'magType': u'ml',
#     u'mmi': 2.73,
#     u'net': u'uw',
#     u'nst': 33,
#     u'place': u'12km SSW of Morton, Washington',
#     u'rms': 0.13,
#     u'sig': 173,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1489534999630,
#     u'title': u'M 3.2 - 12km SSW of Morton, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1496795619040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61257321'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.0493333, 48.5931667, 11.8],
#     u'type': u'Point'},
#    u'id': u'uw61256461',
#    u'properties': {u'alert': None,
#     u'cdi': 4.1,
#     u'code': u'61256461',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61256461&format=geojson',
#     u'dmin': 0.05301,
#     u'felt': 28,
#     u'gap': 78,
#     u'ids': u',uw61256461,us100088fy,',
#     u'mag': 2.59,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 17,
#     u'place': u'6km NNW of Friday Harbor, Washington',
#     u'rms': 0.28,
#     u'sig': 115,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1489276198920,
#     u'title': u'M 2.6 - 6km NNW of Friday Harbor, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1496195942040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61256461'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.9966667, 47.0756667, 4.01],
#     u'type': u'Point'},
#    u'id': u'uw61252706',
#    u'properties': {u'alert': None,
#     u'cdi': 4.1,
#     u'code': u'61252706',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61252706&format=geojson',
#     u'dmin': 0.1069,
#     u'felt': 32,
#     u'gap': 47,
#     u'ids': u',us20008mik,uw61252706,',
#     u'mag': 3.15,
#     u'magType': u'ml',
#     u'mmi': 2.89,
#     u'net': u'uw',
#     u'nst': 37,
#     u'place': u'14km SSW of Cle Elum, Washington',
#     u'rms': 0.17,
#     u'sig': 166,
#     u'sources': u',us,uw,',
#     u'status': u'reviewed',
#     u'time': 1488117558620,
#     u'title': u'M 3.2 - 14km SSW of Cle Elum, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1495594088040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61252706'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.035, 47.4801667, 15.44],
#     u'type': u'Point'},
#    u'id': u'uw61251926',
#    u'properties': {u'alert': u'green',
#     u'cdi': 3.9,
#     u'code': u'61251926',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61251926&format=geojson',
#     u'dmin': 0.1653,
#     u'felt': 3318,
#     u'gap': 34,
#     u'ids': u',at00olt9uf,uw61251926,us20008lp7,',
#     u'mag': 4.09,
#     u'magType': u'ml',
#     u'mmi': 3.56,
#     u'net': u'uw',
#     u'nst': 58,
#     u'place': u'15km WNW of Belfair, Washington',
#     u'rms': 0.25,
#     u'sig': 647,
#     u'sources': u',at,uw,us,',
#     u'status': u'reviewed',
#     u'time': 1487825944050,
#     u'title': u'M 4.1 - 15km WNW of Belfair, Washington',
#     u'tsunami': 1,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1494983976040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61251926'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.6555, 47.3868333, 7.53],
#     u'type': u'Point'},
#    u'id': u'uw61251016',
#    u'properties': {u'alert': None,
#     u'cdi': 4.6,
#     u'code': u'61251016',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61251016&format=geojson',
#     u'dmin': 0.1388,
#     u'felt': 105,
#     u'gap': 64,
#     u'ids': u',uw61251016,us20008kty,',
#     u'mag': 2.65,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 32,
#     u'place': u'1km NW of Wauna, Washington',
#     u'rms': 0.26,
#     u'sig': 156,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1487532468570,
#     u'title': u'M 2.7 - 1km NW of Wauna, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1494983972040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61251016'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-118.5953333, 45.7528333, 6.97],
#     u'type': u'Point'},
#    u'id': u'uw61250371',
#    u'properties': {u'alert': None,
#     u'cdi': 2,
#     u'code': u'61250371',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61250371&format=geojson',
#     u'dmin': 0.3507,
#     u'felt': 1,
#     u'gap': 134,
#     u'ids': u',uw61250371,us20008k2w,',
#     u'mag': 2.85,
#     u'magType': u'ml',
#     u'mmi': 2.28,
#     u'net': u'uw',
#     u'nst': 13,
#     u'place': u'10km SW of Athena, Oregon',
#     u'rms': 0.25,
#     u'sig': 125,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1487195743310,
#     u'title': u'M 2.9 - 10km SW of Athena, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1494637401040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61250371'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.066, 48.6005, 13.76],
#     u'type': u'Point'},
#    u'id': u'uw61248041',
#    u'properties': {u'alert': None,
#     u'cdi': 3.8,
#     u'code': u'61248041',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61248041&format=geojson',
#     u'dmin': 0.06489,
#     u'felt': 27,
#     u'gap': 84,
#     u'ids': u',uw61248041,us20008fpw,',
#     u'mag': 2.77,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 22,
#     u'place': u'8km NNW of Friday Harbor, Washington',
#     u'rms': 0.17,
#     u'sig': 128,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1485981250140,
#     u'title': u'M 2.8 - 8km NNW of Friday Harbor, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1493257121040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61248041'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.0711667, 48.6111667, 14.59],
#     u'type': u'Point'},
#    u'id': u'uw61247601',
#    u'properties': {u'alert': None,
#     u'cdi': 4.3,
#     u'code': u'61247601',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61247601&format=geojson',
#     u'dmin': 0.07578,
#     u'felt': 145,
#     u'gap': 78,
#     u'ids': u',uw61247601,us10007w5s,',
#     u'mag': 3.09,
#     u'magType': u'ml',
#     u'mmi': 2.81,
#     u'net': u'uw',
#     u'nst': 28,
#     u'place': u'9km NNW of Friday Harbor, Washington',
#     u'rms': 0.3,
#     u'sig': 209,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1485774196720,
#     u'title': u'M 3.1 - 9km NNW of Friday Harbor, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1493257118040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61247601'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.0718333, 48.611, 14.62],
#     u'type': u'Point'},
#    u'id': u'uw61247496',
#    u'properties': {u'alert': None,
#     u'cdi': 3.4,
#     u'code': u'61247496',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61247496&format=geojson',
#     u'dmin': 0.07586,
#     u'felt': 29,
#     u'gap': 78,
#     u'ids': u',uw61247496,us10007w4b,',
#     u'mag': 2.81,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 27,
#     u'place': u'9km NNW of Friday Harbor, Washington',
#     u'rms': 0.28,
#     u'sig': 131,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1485743272840,
#     u'title': u'M 2.8 - 9km NNW of Friday Harbor, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1493257118040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61247496'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.0225, 48.7341667, 17.8],
#     u'type': u'Point'},
#    u'id': u'uw61230137',
#    u'properties': {u'alert': None,
#     u'cdi': 3.1,
#     u'code': u'61230137',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61230137&format=geojson',
#     u'dmin': 0.1073,
#     u'felt': 9,
#     u'gap': 114,
#     u'ids': u',uw61230137,us10007v5l,',
#     u'mag': 2.54,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'uw',
#     u'nst': 19,
#     u'place': u'22km N of Friday Harbor, Washington',
#     u'rms': 0.32,
#     u'sig': 102,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1485265441000,
#     u'title': u'M 2.5 - 22km N of Friday Harbor, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1492626658040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61230137'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.5266667, 47.5348333, 42.15],
#     u'type': u'Point'},
#    u'id': u'uw61230002',
#    u'properties': {u'alert': None,
#     u'cdi': 3.4,
#     u'code': u'61230002',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61230002&format=geojson',
#     u'dmin': 0.1949,
#     u'felt': 24,
#     u'gap': 35,
#     u'ids': u',uw61230002,us10007uvs,',
#     u'mag': 3.58,
#     u'magType': u'ml',
#     u'mmi': 2.78,
#     u'net': u'uw',
#     u'nst': 69,
#     u'place': u'25km ENE of Quinault Census Designated Place, Washington',
#     u'rms': 0.16,
#     u'sig': 205,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1485115513900,
#     u'title': u'M 3.6 - 25km ENE of Quinault Census Designated Place, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1492626655040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61230002'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.592, 47.3995, 3.64], u'type': u'Point'},
#    u'id': u'uw61229917',
#    u'properties': {u'alert': None,
#     u'cdi': 4.9,
#     u'code': u'61229917',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61229917&format=geojson',
#     u'dmin': 0.1149,
#     u'felt': 300,
#     u'gap': 40,
#     u'ids': u',uw61229917,us10007utv,',
#     u'mag': 3.13,
#     u'magType': u'ml',
#     u'mmi': 3.05,
#     u'net': u'uw',
#     u'nst': 53,
#     u'place': u'14km ESE of Riverbend, Washington',
#     u'rms': 0.48,
#     u'sig': 298,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1485090145100,
#     u'title': u'M 3.1 - 14km ESE of Riverbend, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1492626655040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61229917'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.4903333, 47.212, 12.59],
#     u'type': u'Point'},
#    u'id': u'uw61228202',
#    u'properties': {u'alert': None,
#     u'cdi': 3.1,
#     u'code': u'61228202',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61228202&format=geojson',
#     u'dmin': 0.0292,
#     u'felt': 25,
#     u'gap': 90,
#     u'ids': u',uw61228202,us10007sji,',
#     u'mag': 2.6,
#     u'magType': u'ml',
#     u'mmi': 2.62,
#     u'net': u'uw',
#     u'nst': 33,
#     u'place': u'3km SSE of Fircrest, Washington',
#     u'rms': 0.24,
#     u'sig': 112,
#     u'sources': u',uw,us,',
#     u'status': u'reviewed',
#     u'time': 1484133636710,
#     u'title': u'M 2.6 - 3km SSE of Fircrest, Washington',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,shakemap,',
#     u'tz': -480,
#     u'updated': 1491006368040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61228202'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-126.7644, 42.3306, 10], u'type': u'Point'},
#    u'id': u'us10007vkw',
#    u'properties': {u'alert': None,
#     u'cdi': 2,
#     u'code': u'10007vkw',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us10007vkw&format=geojson',
#     u'dmin': 1.887,
#     u'felt': 2,
#     u'gap': 239,
#     u'ids': u',us10007vkw,',
#     u'mag': 4.3,
#     u'magType': u'mb',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'191km WSW of Port Orford, Oregon',
#     u'rms': 1.09,
#     u'sig': 285,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 1484063037290,
#     u'title': u'M 4.3 - 191km WSW of Port Orford, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1491006367040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/us10007vkw'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-126.7382, 42.4439, 10], u'type': u'Point'},
#    u'id': u'us10007rky',
#    u'properties': {u'alert': None,
#     u'cdi': 3.4,
#     u'code': u'10007rky',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us10007rky&format=geojson',
#     u'dmin': 1.824,
#     u'felt': 3,
#     u'gap': 235,
#     u'ids': u',us10007rky,',
#     u'mag': 3.2,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'186km W of Port Orford, Oregon',
#     u'rms': 1.24,
#     u'sig': 159,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 1483692514730,
#     u'title': u'M 3.2 - 186km W of Port Orford, Oregon',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',dyfi,geoserve,origin,phase-data,',
#     u'tz': -480,
#     u'updated': 1490658804040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/us10007rky'},
#    u'type': u'Feature'}],
#  u'metadata': {u'api': u'1.5.8',
#   u'count': 30,
#   u'generated': 1501363653000,
#   u'status': 200,
#   u'title': u'USGS Earthquakes',
#   u'url': u'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2017-01-01&endtime=2017-07-01&minlatitude=42&maxlatitude=49&minlongitude=-127&maxlongitude=-116&eventtype=earthquake&producttype=dyfi&minmagnitude=2.5'},
#  u'type': u'FeatureCollection'}

# %%
json_data['bbox']
# Out:
# [-126.8669, 42.3306, 3.64, -118.5953333, 48.7741667, 56.45]

# %%
json_data['metadata']['count']
# Out:
# 30

# %%
event_list = []
for i in range(json_data['metadata']['count']):
    event_line = []
    event_line.append(json_data['features'][i]['id'])
    event_line += json_data['features'][i]['geometry']['coordinates']
    event_line.append(json_data['features'][i]['properties']['alert']),
    event_line.append(json_data['features'][i]['properties']['cdi']),
    event_line.append(json_data['features'][i]['properties']['code']),
    event_line.append(json_data['features'][i]['properties']['felt']),
    event_line.append(json_data['features'][i]['properties']['gap']),
    event_line.append(json_data['features'][i]['properties']['ids'][1:-1]),
    event_line.append(json_data['features'][i]['properties']['mag']),
    event_line.append(json_data['features'][i]['properties']['magType']),
    event_line.append(json_data['features'][i]['properties']['mmi']),
    event_line.append(json_data['features'][i]['properties']['net']),
    event_line.append(json_data['features'][i]['properties']['nst']),
    event_line.append(json_data['features'][i]['properties']['place']),
    event_line.append(json_data['features'][i]['properties']['rms']),
    event_line.append(json_data['features'][i]['properties']['sig']),
    event_line.append(json_data['features'][i]['properties']['sources']),
    event_line.append(json_data['features'][i]['properties']['status']),
    event_line.append(json_data['features'][i]['properties']['time']),
    event_line.append(json_data['features'][i]['properties']['title']),
    event_line.append(json_data['features'][i]['properties']['tsunami']),
    event_line.append(json_data['features'][i]['properties']['type']),
    event_line.append(json_data['features'][i]['properties']['types'][1:-1]),
    event_line.append(json_data['features'][i]['properties']['tz']),
    event_line.append(json_data['features'][i]['properties']['updated']),
    event_line.append(json_data['features'][i]['properties']['url']),

    event_list.append(event_line)
event_list
# Out:
# [[u'uw61297016',
#   -122.6071667,
#   48.7741667,
#   16.27,
#   None,
#   3.8,
#   u'61297016',
#   286,
#   99,
#   u'uw61297016,us1000955h',
#   3.1,
#   u'ml',
#   2.9,
#   u'uw',
#   31,
#   u'4km S of Marietta, Washington',
#   0.21,
#   257,
#   u',uw,us,',
#   u'reviewed',
#   1498725603370,
#   u'M 3.1 - 4km S of Marietta, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1500447547040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61297016'],
#  [u'uw61276967',
#   -121.6675,
#   48.2565,
#   8.47,
#   None,
#   3.8,
#   u'61276967',
#   31,
#   74,
#   u'uw61276967,us20009pki',
#   2.92,
#   u'ml',
#   None,
#   u'uw',
#   24,
#   u'4km W of Darrington, Washington',
#   0.32,
#   143,
#   u',uw,us,',
#   u'reviewed',
#   1498361114610,
#   u'M 2.9 - 4km W of Darrington, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1501131675040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61276967'],
#  [u'uw61293181',
#   -122.8856667,
#   47.8403333,
#   56.45,
#   None,
#   3.8,
#   u'61293181',
#   156,
#   31,
#   u'us20009mws,uw61293181',
#   3.69,
#   u'ml',
#   2.58,
#   u'uw',
#   62,
#   u'17km WSW of Port Ludlow, Washington',
#   0.15,
#   269,
#   u',us,uw,',
#   u'reviewed',
#   1497585325800,
#   u'M 3.7 - 17km WSW of Port Ludlow, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,moment-tensor,origin,phase-data,shakemap',
#   -480,
#   1500163839749,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61293181'],
#  [u'uw61272097',
#   -123.0955,
#   45.0576667,
#   22.48,
#   None,
#   4.1,
#   u'61272097',
#   118,
#   60,
#   u'uw61272097,us10008x4t',
#   2.96,
#   u'ml',
#   2.65,
#   u'uw',
#   32,
#   u'9km NW of Keizer, Oregon',
#   0.22,
#   183,
#   u',uw,us,',
#   u'reviewed',
#   1496332977740,
#   u'M 3.0 - 9km NW of Keizer, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1498847650040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61272097'],
#  [u'uw61268327',
#   -122.5818333,
#   47.5815,
#   24.03,
#   None,
#   3.4,
#   u'61268327',
#   18,
#   37,
#   u'uw61268327,us10008u20',
#   2.77,
#   u'ml',
#   None,
#   u'uw',
#   43,
#   u'1km ESE of Enetai, Washington',
#   0.24,
#   124,
#   u',uw,us,',
#   u'reviewed',
#   1495399431280,
#   u'M 2.8 - 1km ESE of Enetai, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1498314661040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61268327'],
#  [u'uw61267487',
#   -122.5891667,
#   47.5931667,
#   25.11,
#   None,
#   2.7,
#   u'61267487',
#   8,
#   36,
#   u'uw61267487,us10008tdr',
#   2.5,
#   u'ml',
#   None,
#   u'uw',
#   33,
#   u'1km NE of Enetai, Washington',
#   0.32,
#   98,
#   u',uw,us,',
#   u'reviewed',
#   1495131332560,
#   u'M 2.5 - 1km NE of Enetai, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1497540178040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61267487'],
#  [u'uw61265222',
#   -122.4663333,
#   47.9616667,
#   23.67,
#   None,
#   4.1,
#   u'61265222',
#   594,
#   55,
#   u'uw61265222,us10008rit',
#   3.43,
#   u'ml',
#   2.9,
#   u'uw',
#   39,
#   u'6km SE of Freeland, Washington',
#   0.19,
#   425,
#   u',uw,us,',
#   u'reviewed',
#   1494525395950,
#   u'M 3.4 - 6km SE of Freeland, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1496027875574,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61265222'],
#  [u'uw61265082',
#   -122.5646667,
#   47.5896667,
#   21.55,
#   None,
#   3.4,
#   u'61265082',
#   31,
#   37,
#   u'uw61265082,us10008rgc',
#   2.6,
#   u'ml',
#   None,
#   u'uw',
#   41,
#   u'2km ENE of Enetai, Washington',
#   0.15,
#   115,
#   u',uw,us,',
#   u'reviewed',
#   1494495396720,
#   u'M 2.6 - 2km ENE of Enetai, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1497340038040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61265082'],
#  [u'uw61265017',
#   -122.5841667,
#   47.5886667,
#   24.06,
#   None,
#   4.5,
#   u'61265017',
#   946,
#   37,
#   u'us10008rey,uw61265017',
#   3.47,
#   u'ml',
#   3.03,
#   u'uw',
#   60,
#   u'1km ENE of Enetai, Washington',
#   0.2,
#   611,
#   u',us,uw,',
#   u'reviewed',
#   1494488124720,
#   u'M 3.5 - 1km ENE of Enetai, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1496219077040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61265017'],
#  [u'uw61264612',
#   -122.584,
#   47.5791667,
#   24.5,
#   None,
#   3.6,
#   u'61264612',
#   795,
#   37,
#   u'uw61264612,us10008r2n',
#   3.38,
#   u'ml',
#   2.94,
#   u'uw',
#   57,
#   u'1km ESE of Enetai, Washington',
#   0.21,
#   462,
#   u',uw,us,',
#   u'reviewed',
#   1494404072090,
#   u'M 3.4 - 1km ESE of Enetai, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1497337558040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61264612'],
#  [u'uw61277931',
#   -122.5995,
#   47.5693333,
#   26.51,
#   None,
#   3.4,
#   u'61277931',
#   229,
#   41,
#   u'uw61277931,us10008nz4',
#   3.31,
#   u'ml',
#   2.77,
#   u'uw',
#   27,
#   u'1km S of Enetai, Washington',
#   0.16,
#   246,
#   u',uw,us,',
#   u'reviewed',
#   1493839236470,
#   u'M 3.3 - 1km S of Enetai, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1501298178040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61277931'],
#  [u'uw61272661',
#   -122.7573333,
#   48.1763333,
#   23.26,
#   None,
#   4.1,
#   u'61272661',
#   172,
#   36,
#   u'uw61272661,us10008j6a',
#   3.01,
#   u'ml',
#   2.52,
#   u'uw',
#   36,
#   u'7km N of Port Townsend, Washington',
#   0.25,
#   210,
#   u',uw,us,',
#   u'reviewed',
#   1492664823640,
#   u'M 3.0 - 7km N of Port Townsend, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1499737718040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61272661'],
#  [u'us10008hyg',
#   -124.6165,
#   44.4392,
#   36.68,
#   None,
#   1,
#   u'10008hyg',
#   0,
#   140,
#   u'us10008hyg,uw61271261',
#   2.7,
#   u'ml',
#   None,
#   u'us',
#   None,
#   u'43km W of Waldport, Oregon',
#   0.86,
#   112,
#   u',us,uw,',
#   u'reviewed',
#   1492283203970,
#   u'M 2.7 - 43km W of Waldport, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1499278201040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/us10008hyg'],
#  [u'us10008hwk',
#   -124.6193,
#   44.4357,
#   37.67,
#   None,
#   3.8,
#   u'10008hwk',
#   26,
#   130,
#   u'us10008hwk,uw61271121',
#   3.9,
#   u'mb',
#   3.16,
#   u'us',
#   None,
#   u'43km W of Waldport, Oregon',
#   1.18,
#   244,
#   u',us,uw,',
#   u'reviewed',
#   1492267715220,
#   u'M 3.9 - 43km W of Waldport, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1499278201040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/us10008hwk'],
#  [u'us10008guf',
#   -126.8669,
#   43.4224,
#   10,
#   None,
#   2.7,
#   u'10008guf',
#   4,
#   181,
#   u'us10008guf',
#   4.2,
#   u'mb',
#   None,
#   u'us',
#   None,
#   u'202km W of Bandon, Oregon',
#   0.9,
#   272,
#   u',us,',
#   u'reviewed',
#   1491961505820,
#   u'M 4.2 - 202km W of Bandon, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1499278197040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/us10008guf'],
#  [u'uw61257321',
#   -122.332,
#   46.4483333,
#   11.75,
#   None,
#   4.3,
#   u'61257321',
#   34,
#   70,
#   u'uw61257321,us20008s7h',
#   3.21,
#   u'ml',
#   2.73,
#   u'uw',
#   33,
#   u'12km SSW of Morton, Washington',
#   0.13,
#   173,
#   u',uw,us,',
#   u'reviewed',
#   1489534999630,
#   u'M 3.2 - 12km SSW of Morton, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1496795619040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61257321'],
#  [u'uw61256461',
#   -123.0493333,
#   48.5931667,
#   11.8,
#   None,
#   4.1,
#   u'61256461',
#   28,
#   78,
#   u'uw61256461,us100088fy',
#   2.59,
#   u'ml',
#   None,
#   u'uw',
#   17,
#   u'6km NNW of Friday Harbor, Washington',
#   0.28,
#   115,
#   u',uw,us,',
#   u'reviewed',
#   1489276198920,
#   u'M 2.6 - 6km NNW of Friday Harbor, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1496195942040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61256461'],
#  [u'uw61252706',
#   -120.9966667,
#   47.0756667,
#   4.01,
#   None,
#   4.1,
#   u'61252706',
#   32,
#   47,
#   u'us20008mik,uw61252706',
#   3.15,
#   u'ml',
#   2.89,
#   u'uw',
#   37,
#   u'14km SSW of Cle Elum, Washington',
#   0.17,
#   166,
#   u',us,uw,',
#   u'reviewed',
#   1488117558620,
#   u'M 3.2 - 14km SSW of Cle Elum, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1495594088040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61252706'],
#  [u'uw61251926',
#   -123.035,
#   47.4801667,
#   15.44,
#   u'green',
#   3.9,
#   u'61251926',
#   3318,
#   34,
#   u'at00olt9uf,uw61251926,us20008lp7',
#   4.09,
#   u'ml',
#   3.56,
#   u'uw',
#   58,
#   u'15km WNW of Belfair, Washington',
#   0.25,
#   647,
#   u',at,uw,us,',
#   u'reviewed',
#   1487825944050,
#   u'M 4.1 - 15km WNW of Belfair, Washington',
#   1,
#   u'earthquake',
#   u'dyfi,geoserve,impact-link,losspager,moment-tensor,origin,phase-data,shakemap',
#   -480,
#   1494983976040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61251926'],
#  [u'uw61251016',
#   -122.6555,
#   47.3868333,
#   7.53,
#   None,
#   4.6,
#   u'61251016',
#   105,
#   64,
#   u'uw61251016,us20008kty',
#   2.65,
#   u'ml',
#   None,
#   u'uw',
#   32,
#   u'1km NW of Wauna, Washington',
#   0.26,
#   156,
#   u',uw,us,',
#   u'reviewed',
#   1487532468570,
#   u'M 2.7 - 1km NW of Wauna, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1494983972040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61251016'],
#  [u'uw61250371',
#   -118.5953333,
#   45.7528333,
#   6.97,
#   None,
#   2,
#   u'61250371',
#   1,
#   134,
#   u'uw61250371,us20008k2w',
#   2.85,
#   u'ml',
#   2.28,
#   u'uw',
#   13,
#   u'10km SW of Athena, Oregon',
#   0.25,
#   125,
#   u',uw,us,',
#   u'reviewed',
#   1487195743310,
#   u'M 2.9 - 10km SW of Athena, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1494637401040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61250371'],
#  [u'uw61248041',
#   -123.066,
#   48.6005,
#   13.76,
#   None,
#   3.8,
#   u'61248041',
#   27,
#   84,
#   u'uw61248041,us20008fpw',
#   2.77,
#   u'ml',
#   None,
#   u'uw',
#   22,
#   u'8km NNW of Friday Harbor, Washington',
#   0.17,
#   128,
#   u',uw,us,',
#   u'reviewed',
#   1485981250140,
#   u'M 2.8 - 8km NNW of Friday Harbor, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1493257121040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61248041'],
#  [u'uw61247601',
#   -123.0711667,
#   48.6111667,
#   14.59,
#   None,
#   4.3,
#   u'61247601',
#   145,
#   78,
#   u'uw61247601,us10007w5s',
#   3.09,
#   u'ml',
#   2.81,
#   u'uw',
#   28,
#   u'9km NNW of Friday Harbor, Washington',
#   0.3,
#   209,
#   u',uw,us,',
#   u'reviewed',
#   1485774196720,
#   u'M 3.1 - 9km NNW of Friday Harbor, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1493257118040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61247601'],
#  [u'uw61247496',
#   -123.0718333,
#   48.611,
#   14.62,
#   None,
#   3.4,
#   u'61247496',
#   29,
#   78,
#   u'uw61247496,us10007w4b',
#   2.81,
#   u'ml',
#   None,
#   u'uw',
#   27,
#   u'9km NNW of Friday Harbor, Washington',
#   0.28,
#   131,
#   u',uw,us,',
#   u'reviewed',
#   1485743272840,
#   u'M 2.8 - 9km NNW of Friday Harbor, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1493257118040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61247496'],
#  [u'uw61230137',
#   -123.0225,
#   48.7341667,
#   17.8,
#   None,
#   3.1,
#   u'61230137',
#   9,
#   114,
#   u'uw61230137,us10007v5l',
#   2.54,
#   u'ml',
#   None,
#   u'uw',
#   19,
#   u'22km N of Friday Harbor, Washington',
#   0.32,
#   102,
#   u',uw,us,',
#   u'reviewed',
#   1485265441000,
#   u'M 2.5 - 22km N of Friday Harbor, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1492626658040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61230137'],
#  [u'uw61230002',
#   -123.5266667,
#   47.5348333,
#   42.15,
#   None,
#   3.4,
#   u'61230002',
#   24,
#   35,
#   u'uw61230002,us10007uvs',
#   3.58,
#   u'ml',
#   2.78,
#   u'uw',
#   69,
#   u'25km ENE of Quinault Census Designated Place, Washington',
#   0.16,
#   205,
#   u',uw,us,',
#   u'reviewed',
#   1485115513900,
#   u'M 3.6 - 25km ENE of Quinault Census Designated Place, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1492626655040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61230002'],
#  [u'uw61229917',
#   -121.592,
#   47.3995,
#   3.64,
#   None,
#   4.9,
#   u'61229917',
#   300,
#   40,
#   u'uw61229917,us10007utv',
#   3.13,
#   u'ml',
#   3.05,
#   u'uw',
#   53,
#   u'14km ESE of Riverbend, Washington',
#   0.48,
#   298,
#   u',uw,us,',
#   u'reviewed',
#   1485090145100,
#   u'M 3.1 - 14km ESE of Riverbend, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1492626655040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61229917'],
#  [u'uw61228202',
#   -122.4903333,
#   47.212,
#   12.59,
#   None,
#   3.1,
#   u'61228202',
#   25,
#   90,
#   u'uw61228202,us10007sji',
#   2.6,
#   u'ml',
#   2.62,
#   u'uw',
#   33,
#   u'3km SSE of Fircrest, Washington',
#   0.24,
#   112,
#   u',uw,us,',
#   u'reviewed',
#   1484133636710,
#   u'M 2.6 - 3km SSE of Fircrest, Washington',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data,shakemap',
#   -480,
#   1491006368040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/uw61228202'],
#  [u'us10007vkw',
#   -126.7644,
#   42.3306,
#   10,
#   None,
#   2,
#   u'10007vkw',
#   2,
#   239,
#   u'us10007vkw',
#   4.3,
#   u'mb',
#   None,
#   u'us',
#   None,
#   u'191km WSW of Port Orford, Oregon',
#   1.09,
#   285,
#   u',us,',
#   u'reviewed',
#   1484063037290,
#   u'M 4.3 - 191km WSW of Port Orford, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1491006367040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/us10007vkw'],
#  [u'us10007rky',
#   -126.7382,
#   42.4439,
#   10,
#   None,
#   3.4,
#   u'10007rky',
#   3,
#   235,
#   u'us10007rky',
#   3.2,
#   u'ml',
#   None,
#   u'us',
#   None,
#   u'186km W of Port Orford, Oregon',
#   1.24,
#   159,
#   u',us,',
#   u'reviewed',
#   1483692514730,
#   u'M 3.2 - 186km W of Port Orford, Oregon',
#   0,
#   u'earthquake',
#   u'dyfi,geoserve,origin,phase-data',
#   -480,
#   1490658804040,
#   u'https://earthquake.usgs.gov/earthquakes/eventpage/us10007rky']]

# %%
cols = ['id', 'lat', 'long', 'depth', 'alert', 'cdi', 'code', 'felt', 'gap', 'ids', 'mag', 'magType', \
        'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time', 'title', 'tsunami', \
        'type', 'types', 'tz', 'updated', 'url']
quakes = pd.DataFrame(event_list, columns = cols)

# %%
quakes.types
# Out:
# 0              dyfi,geoserve,origin,phase-data,shakemap
# 1                       dyfi,geoserve,origin,phase-data
# 2     dyfi,geoserve,moment-tensor,origin,phase-data,...
# 3              dyfi,geoserve,origin,phase-data,shakemap
# 4                       dyfi,geoserve,origin,phase-data
# 5                       dyfi,geoserve,origin,phase-data
# 6              dyfi,geoserve,origin,phase-data,shakemap
# 7                       dyfi,geoserve,origin,phase-data
# 8              dyfi,geoserve,origin,phase-data,shakemap
# 9              dyfi,geoserve,origin,phase-data,shakemap
# 10             dyfi,geoserve,origin,phase-data,shakemap
# 11             dyfi,geoserve,origin,phase-data,shakemap
# 12                      dyfi,geoserve,origin,phase-data
# 13             dyfi,geoserve,origin,phase-data,shakemap
# 14                      dyfi,geoserve,origin,phase-data
# 15             dyfi,geoserve,origin,phase-data,shakemap
# 16                      dyfi,geoserve,origin,phase-data
# 17             dyfi,geoserve,origin,phase-data,shakemap
# 18    dyfi,geoserve,impact-link,losspager,moment-ten...
# 19                      dyfi,geoserve,origin,phase-data
# 20             dyfi,geoserve,origin,phase-data,shakemap
# 21                      dyfi,geoserve,origin,phase-data
# 22             dyfi,geoserve,origin,phase-data,shakemap
# 23                      dyfi,geoserve,origin,phase-data
# 24                      dyfi,geoserve,origin,phase-data
# 25             dyfi,geoserve,origin,phase-data,shakemap
# 26             dyfi,geoserve,origin,phase-data,shakemap
# 27             dyfi,geoserve,origin,phase-data,shakemap
# 28                      dyfi,geoserve,origin,phase-data
# 29                      dyfi,geoserve,origin,phase-data
# Name: types, dtype: object

# %%
quakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 28 columns):
# id         30 non-null object
# lat        30 non-null float64
# long       30 non-null float64
# depth      30 non-null float64
# alert      1 non-null object
# cdi        30 non-null float64
# code       30 non-null object
# felt       30 non-null int64
# gap        30 non-null int64
# ids        30 non-null object
# mag        30 non-null float64
# magType    30 non-null object
# mmi        17 non-null float64
# net        30 non-null object
# nst        25 non-null float64
# place      30 non-null object
# rms        30 non-null float64
# sig        30 non-null int64
# sources    30 non-null object
# status     30 non-null object
# time       30 non-null int64
# title      30 non-null object
# tsunami    30 non-null int64
# type       30 non-null object
# types      30 non-null object
# tz         30 non-null int64
# updated    30 non-null int64
# url        30 non-null object
# dtypes: float64(8), int64(7), object(13)
# memory usage: 6.6+ KB

# %%
quakes.types.unique()
# Out:
# array([u'dyfi,geoserve,origin,phase-data,shakemap',
#        u'dyfi,geoserve,origin,phase-data',
#        u'dyfi,geoserve,moment-tensor,origin,phase-data,shakemap',
#        u'dyfi,geoserve,impact-link,losspager,moment-tensor,origin,phase-data,shakemap'], dtype=object)

# %%
quakes
# Out:
#             id         lat       long  depth  alert  cdi      code  felt  gap  \
# 0   uw61297016 -122.607167  48.774167  16.27   None  3.8  61297016   286   99
# 1   uw61276967 -121.667500  48.256500   8.47   None  3.8  61276967    31   74
# 2   uw61293181 -122.885667  47.840333  56.45   None  3.8  61293181   156   31
# 3   uw61272097 -123.095500  45.057667  22.48   None  4.1  61272097   118   60
# 4   uw61268327 -122.581833  47.581500  24.03   None  3.4  61268327    18   37
# 5   uw61267487 -122.589167  47.593167  25.11   None  2.7  61267487     8   36
# 6   uw61265222 -122.466333  47.961667  23.67   None  4.1  61265222   594   55
# 7   uw61265082 -122.564667  47.589667  21.55   None  3.4  61265082    31   37
# 8   uw61265017 -122.584167  47.588667  24.06   None  4.5  61265017   946   37
# 9   uw61264612 -122.584000  47.579167  24.50   None  3.6  61264612   795   37
# 10  uw61277931 -122.599500  47.569333  26.51   None  3.4  61277931   229   41
# 11  uw61272661 -122.757333  48.176333  23.26   None  4.1  61272661   172   36
# 12  us10008hyg -124.616500  44.439200  36.68   None  1.0  10008hyg     0  140
# 13  us10008hwk -124.619300  44.435700  37.67   None  3.8  10008hwk    26  130
# 14  us10008guf -126.866900  43.422400  10.00   None  2.7  10008guf     4  181
# 15  uw61257321 -122.332000  46.448333  11.75   None  4.3  61257321    34   70
# 16  uw61256461 -123.049333  48.593167  11.80   None  4.1  61256461    28   78
# 17  uw61252706 -120.996667  47.075667   4.01   None  4.1  61252706    32   47
# 18  uw61251926 -123.035000  47.480167  15.44  green  3.9  61251926  3318   34
# 19  uw61251016 -122.655500  47.386833   7.53   None  4.6  61251016   105   64
# 20  uw61250371 -118.595333  45.752833   6.97   None  2.0  61250371     1  134
# 21  uw61248041 -123.066000  48.600500  13.76   None  3.8  61248041    27   84
# 22  uw61247601 -123.071167  48.611167  14.59   None  4.3  61247601   145   78
# 23  uw61247496 -123.071833  48.611000  14.62   None  3.4  61247496    29   78
# 24  uw61230137 -123.022500  48.734167  17.80   None  3.1  61230137     9  114
# 25  uw61230002 -123.526667  47.534833  42.15   None  3.4  61230002    24   35
# 26  uw61229917 -121.592000  47.399500   3.64   None  4.9  61229917   300   40
# 27  uw61228202 -122.490333  47.212000  12.59   None  3.1  61228202    25   90
# 28  us10007vkw -126.764400  42.330600  10.00   None  2.0  10007vkw     2  239
# 29  us10007rky -126.738200  42.443900  10.00   None  3.4  10007rky     3  235
#
#                                  ids  \
# 0              uw61297016,us1000955h
# 1              uw61276967,us20009pki
# 2              us20009mws,uw61293181
# 3              uw61272097,us10008x4t
# 4              uw61268327,us10008u20
# 5              uw61267487,us10008tdr
# 6              uw61265222,us10008rit
# 7              uw61265082,us10008rgc
# 8              us10008rey,uw61265017
# 9              uw61264612,us10008r2n
# 10             uw61277931,us10008nz4
# 11             uw61272661,us10008j6a
# 12             us10008hyg,uw61271261
# 13             us10008hwk,uw61271121
# 14                        us10008guf
# 15             uw61257321,us20008s7h
# 16             uw61256461,us100088fy
# 17             us20008mik,uw61252706
# 18  at00olt9uf,uw61251926,us20008lp7
# 19             uw61251016,us20008kty
# 20             uw61250371,us20008k2w
# 21             uw61248041,us20008fpw
# 22             uw61247601,us10007w5s
# 23             uw61247496,us10007w4b
# 24             uw61230137,us10007v5l
# 25             uw61230002,us10007uvs
# 26             uw61229917,us10007utv
# 27             uw61228202,us10007sji
# 28                        us10007vkw
# 29                        us10007rky
#
#                           ...                             sources    status  \
# 0                         ...                             ,uw,us,  reviewed
# 1                         ...                             ,uw,us,  reviewed
# 2                         ...                             ,us,uw,  reviewed
# 3                         ...                             ,uw,us,  reviewed
# 4                         ...                             ,uw,us,  reviewed
# 5                         ...                             ,uw,us,  reviewed
# 6                         ...                             ,uw,us,  reviewed
# 7                         ...                             ,uw,us,  reviewed
# 8                         ...                             ,us,uw,  reviewed
# 9                         ...                             ,uw,us,  reviewed
# 10                        ...                             ,uw,us,  reviewed
# 11                        ...                             ,uw,us,  reviewed
# 12                        ...                             ,us,uw,  reviewed
# 13                        ...                             ,us,uw,  reviewed
# 14                        ...                                ,us,  reviewed
# 15                        ...                             ,uw,us,  reviewed
# 16                        ...                             ,uw,us,  reviewed
# 17                        ...                             ,us,uw,  reviewed
# 18                        ...                          ,at,uw,us,  reviewed
# 19                        ...                             ,uw,us,  reviewed
# 20                        ...                             ,uw,us,  reviewed
# 21                        ...                             ,uw,us,  reviewed
# 22                        ...                             ,uw,us,  reviewed
# 23                        ...                             ,uw,us,  reviewed
# 24                        ...                             ,uw,us,  reviewed
# 25                        ...                             ,uw,us,  reviewed
# 26                        ...                             ,uw,us,  reviewed
# 27                        ...                             ,uw,us,  reviewed
# 28                        ...                                ,us,  reviewed
# 29                        ...                                ,us,  reviewed
#
#              time                                              title  tsunami  \
# 0   1498725603370              M 3.1 - 4km S of Marietta, Washington        0
# 1   1498361114610            M 2.9 - 4km W of Darrington, Washington        0
# 2   1497585325800        M 3.7 - 17km WSW of Port Ludlow, Washington        0
# 3   1496332977740                   M 3.0 - 9km NW of Keizer, Oregon        0
# 4   1495399431280              M 2.8 - 1km ESE of Enetai, Washington        0
# 5   1495131332560               M 2.5 - 1km NE of Enetai, Washington        0
# 6   1494525395950             M 3.4 - 6km SE of Freeland, Washington        0
# 7   1494495396720              M 2.6 - 2km ENE of Enetai, Washington        0
# 8   1494488124720              M 3.5 - 1km ENE of Enetai, Washington        0
# 9   1494404072090              M 3.4 - 1km ESE of Enetai, Washington        0
# 10  1493839236470                M 3.3 - 1km S of Enetai, Washington        0
# 11  1492664823640         M 3.0 - 7km N of Port Townsend, Washington        0
# 12  1492283203970                 M 2.7 - 43km W of Waldport, Oregon        0
# 13  1492267715220                 M 3.9 - 43km W of Waldport, Oregon        0
# 14  1491961505820                  M 4.2 - 202km W of Bandon, Oregon        0
# 15  1489534999630             M 3.2 - 12km SSW of Morton, Washington        0
# 16  1489276198920       M 2.6 - 6km NNW of Friday Harbor, Washington        0
# 17  1488117558620           M 3.2 - 14km SSW of Cle Elum, Washington        0
# 18  1487825944050            M 4.1 - 15km WNW of Belfair, Washington        1
# 19  1487532468570                M 2.7 - 1km NW of Wauna, Washington        0
# 20  1487195743310                  M 2.9 - 10km SW of Athena, Oregon        0
# 21  1485981250140       M 2.8 - 8km NNW of Friday Harbor, Washington        0
# 22  1485774196720       M 3.1 - 9km NNW of Friday Harbor, Washington        0
# 23  1485743272840       M 2.8 - 9km NNW of Friday Harbor, Washington        0
# 24  1485265441000        M 2.5 - 22km N of Friday Harbor, Washington        0
# 25  1485115513900  M 3.6 - 25km ENE of Quinault Census Designated...        0
# 26  1485090145100          M 3.1 - 14km ESE of Riverbend, Washington        0
# 27  1484133636710            M 2.6 - 3km SSE of Fircrest, Washington        0
# 28  1484063037290           M 4.3 - 191km WSW of Port Orford, Oregon        0
# 29  1483692514730             M 3.2 - 186km W of Port Orford, Oregon        0
#
#           type                                              types   tz  \
# 0   earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 1   earthquake                    dyfi,geoserve,origin,phase-data -480
# 2   earthquake  dyfi,geoserve,moment-tensor,origin,phase-data,... -480
# 3   earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 4   earthquake                    dyfi,geoserve,origin,phase-data -480
# 5   earthquake                    dyfi,geoserve,origin,phase-data -480
# 6   earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 7   earthquake                    dyfi,geoserve,origin,phase-data -480
# 8   earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 9   earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 10  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 11  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 12  earthquake                    dyfi,geoserve,origin,phase-data -480
# 13  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 14  earthquake                    dyfi,geoserve,origin,phase-data -480
# 15  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 16  earthquake                    dyfi,geoserve,origin,phase-data -480
# 17  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 18  earthquake  dyfi,geoserve,impact-link,losspager,moment-ten... -480
# 19  earthquake                    dyfi,geoserve,origin,phase-data -480
# 20  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 21  earthquake                    dyfi,geoserve,origin,phase-data -480
# 22  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 23  earthquake                    dyfi,geoserve,origin,phase-data -480
# 24  earthquake                    dyfi,geoserve,origin,phase-data -480
# 25  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 26  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 27  earthquake           dyfi,geoserve,origin,phase-data,shakemap -480
# 28  earthquake                    dyfi,geoserve,origin,phase-data -480
# 29  earthquake                    dyfi,geoserve,origin,phase-data -480
#
#           updated                                                url
# 0   1500447547040  https://earthquake.usgs.gov/earthquakes/eventp...
# 1   1501131675040  https://earthquake.usgs.gov/earthquakes/eventp...
# 2   1500163839749  https://earthquake.usgs.gov/earthquakes/eventp...
# 3   1498847650040  https://earthquake.usgs.gov/earthquakes/eventp...
# 4   1498314661040  https://earthquake.usgs.gov/earthquakes/eventp...
# 5   1497540178040  https://earthquake.usgs.gov/earthquakes/eventp...
# 6   1496027875574  https://earthquake.usgs.gov/earthquakes/eventp...
# 7   1497340038040  https://earthquake.usgs.gov/earthquakes/eventp...
# 8   1496219077040  https://earthquake.usgs.gov/earthquakes/eventp...
# 9   1497337558040  https://earthquake.usgs.gov/earthquakes/eventp...
# 10  1501298178040  https://earthquake.usgs.gov/earthquakes/eventp...
# 11  1499737718040  https://earthquake.usgs.gov/earthquakes/eventp...
# 12  1499278201040  https://earthquake.usgs.gov/earthquakes/eventp...
# 13  1499278201040  https://earthquake.usgs.gov/earthquakes/eventp...
# 14  1499278197040  https://earthquake.usgs.gov/earthquakes/eventp...
# 15  1496795619040  https://earthquake.usgs.gov/earthquakes/eventp...
# 16  1496195942040  https://earthquake.usgs.gov/earthquakes/eventp...
# 17  1495594088040  https://earthquake.usgs.gov/earthquakes/eventp...
# 18  1494983976040  https://earthquake.usgs.gov/earthquakes/eventp...
# 19  1494983972040  https://earthquake.usgs.gov/earthquakes/eventp...
# 20  1494637401040  https://earthquake.usgs.gov/earthquakes/eventp...
# 21  1493257121040  https://earthquake.usgs.gov/earthquakes/eventp...
# 22  1493257118040  https://earthquake.usgs.gov/earthquakes/eventp...
# 23  1493257118040  https://earthquake.usgs.gov/earthquakes/eventp...
# 24  1492626658040  https://earthquake.usgs.gov/earthquakes/eventp...
# 25  1492626655040  https://earthquake.usgs.gov/earthquakes/eventp...
# 26  1492626655040  https://earthquake.usgs.gov/earthquakes/eventp...
# 27  1491006368040  https://earthquake.usgs.gov/earthquakes/eventp...
# 28  1491006367040  https://earthquake.usgs.gov/earthquakes/eventp...
# 29  1490658804040  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [30 rows x 28 columns]

# %% [markdown]
# ## Pull actual data for continental US using USGS API.
#
# This was done in sections, by editing and re-running the code below

# %%
import requests

# %%
# This is the ComCat reqeust to return earthquakes in WA and OR by lat long box, with magnitude > 2.5 
# I did not limit it to dyfi (did you feel it) events, because I want to also examine any changes in 
# quake frenqency.  I pulled all data from 1970 to end of June 2017.

# %%
wc_url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1970-01-01&endtime=1974-12-31 \
&minlatitude=25&maxlatitude=49&minlongitude=-130&maxlongitude=-100\
&eventtype=earthquake&minmagnitude=2.5"

# %%
ec_url = "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1970-01-01&endtime=1999-12-31\
&minlatitude=25&maxlatitude=49&minlongitude=-99.9999&maxlongitude=-67\
&eventtype=earthquake&minmagnitude=2.5"

# %%
wc_url
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1970-01-01&endtime=1974-12-31 &minlatitude=25&maxlatitude=49&minlongitude=-130&maxlongitude=-100&eventtype=earthquake&minmagnitude=2.5'

# %%
# Please do not re-run this section, it pulls a lot of data from the USGS comcat server.   I can help minimize
# the request if you'd like to see a demo

# # Package the request, send the request and catch the response: r
# r = requests.get(wc_url)

# # Decode the JSON data into a dictionary: json_data
# json_data = r.json()

# %%
r
# Out:
# <Response [200]>

# %%
json_data
# Out:
# {u'bbox': [-129.651, 25.781, -1.832, -100.693, 48.952, 62.234],
#  u'features': [{u'geometry': {u'coordinates': [-121.8735, 36.593, 4.946],
#     u'type': u'Point'},
#    u'id': u'nc1022389',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022389',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022389&format=geojson',
#     u'dmin': 0.03694,
#     u'felt': None,
#     u'gap': 167,
#     u'ids': u',nc1022389,',
#     u'mag': 3.39,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 63,
#     u'place': u'Central California',
#     u'rms': 0.11,
#     u'sig': 177,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157660096830,
#     u'title': u'M 3.4 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756564940,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022389'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4645, 36.929, 3.946],
#     u'type': u'Point'},
#    u'id': u'nc1022388',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022388',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022388&format=geojson',
#     u'dmin': 0.04144,
#     u'felt': None,
#     u'gap': 61,
#     u'ids': u',nc1022388,',
#     u'mag': 2.99,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 25,
#     u'place': u'Central California',
#     u'rms': 0.1,
#     u'sig': 138,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157646814820,
#     u'title': u'M 3.0 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756553974,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022388'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.1288333, 29.9076667, 6],
#     u'type': u'Point'},
#    u'id': u'ci3319041',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3319041',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3319041&format=geojson',
#     u'dmin': 2.734,
#     u'felt': None,
#     u'gap': 304,
#     u'ids': u',ci3319041,',
#     u'mag': 4.58,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 20,
#     u'place': u'206km SSE of Maneadero, B.C., MX',
#     u'rms': 41.96,
#     u'sig': 323,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157641167870,
#     u'title': u'M 4.6 - 206km SSE of Maneadero, B.C., MX',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454032083640,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3319041'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.402, 30.424, 33], u'type': u'Point'},
#    u'id': u'usp00009ad',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'p00009ad',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp00009ad&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': None,
#     u'ids': u',usp00009ad,',
#     u'mag': 4,
#     u'magType': u'mb',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'offshore Baja California, Mexico',
#     u'rms': None,
#     u'sig': 246,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 157641135300,
#     u'title': u'M 4.0 - offshore Baja California, Mexico',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,',
#     u'tz': None,
#     u'updated': 1415316088071,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp00009ad'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.185, 30.757, 33], u'type': u'Point'},
#    u'id': u'usp000099y',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'p000099y',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000099y&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': None,
#     u'ids': u',ci3319049,usp000099y,',
#     u'mag': 4.2,
#     u'magType': u'mb',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'offshore Baja California, Mexico',
#     u'rms': None,
#     u'sig': 271,
#     u'sources': u',ci,us,',
#     u'status': u'reviewed',
#     u'time': 157550821500,
#     u'title': u'M 4.2 - offshore Baja California, Mexico',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454030304990,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000099y'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.2928333, 37.9265, 6.209],
#     u'type': u'Point'},
#    u'id': u'nc1022384',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022384',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022384&format=geojson',
#     u'dmin': 0.05045,
#     u'felt': None,
#     u'gap': 65,
#     u'ids': u',nc1022384,usp000099w,',
#     u'mag': 3.5,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 39,
#     u'place': u'San Francisco Bay area, California',
#     u'rms': 0.08,
#     u'sig': 188,
#     u'sources': u',nc,us,',
#     u'status': u'reviewed',
#     u'time': 157542705860,
#     u'title': u'M 3.5 - San Francisco Bay area, California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756542660,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022384'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-115.9593333, 30.6926667, 6],
#     u'type': u'Point'},
#    u'id': u'ci3319043',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3319043',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3319043&format=geojson',
#     u'dmin': 1.956,
#     u'felt': None,
#     u'gap': 311,
#     u'ids': u',ci3319043,',
#     u'mag': 3.59,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 6,
#     u'place': u'128km SSE of Maneadero, B.C., MX',
#     u'rms': 0.44,
#     u'sig': 198,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157510527320,
#     u'title': u'M 3.6 - 128km SSE of Maneadero, B.C., MX',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031766790,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3319043'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.473, 30.7335, 6], u'type': u'Point'},
#    u'id': u'ci3319050',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3319050',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3319050&format=geojson',
#     u'dmin': 1.936,
#     u'felt': None,
#     u'gap': 322,
#     u'ids': u',ci3319050,',
#     u'mag': 3.9,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 12,
#     u'place': u'110km S of Maneadero, B.C., MX',
#     u'rms': 0.77,
#     u'sig': 234,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157506394430,
#     u'title': u'M 3.9 - 110km S of Maneadero, B.C., MX',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454032083100,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3319050'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.075, 30.86, 33], u'type': u'Point'},
#    u'id': u'usp000099k',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'p000099k',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000099k&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': None,
#     u'ids': u',usp000099k,',
#     u'mag': 4.7,
#     u'magType': u'mb',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'Baja California, Mexico',
#     u'rms': None,
#     u'sig': 340,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 157504718800,
#     u'title': u'M 4.7 - Baja California, Mexico',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,',
#     u'tz': None,
#     u'updated': 1415316088042,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000099k'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4596667, 36.932, 6.066],
#     u'type': u'Point'},
#    u'id': u'nc1022383',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022383',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022383&format=geojson',
#     u'dmin': 0.04595,
#     u'felt': None,
#     u'gap': 46,
#     u'ids': u',nc1022383,',
#     u'mag': 3.44,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 55,
#     u'place': u'Central California',
#     u'rms': 0.08,
#     u'sig': 182,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157504086400,
#     u'title': u'M 3.4 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756526860,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022383'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.2596667, 36.8908333, 5.616],
#     u'type': u'Point'},
#    u'id': u'nc1022381',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022381',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022381&format=geojson',
#     u'dmin': 0.04054,
#     u'felt': None,
#     u'gap': 88,
#     u'ids': u',nc1022381,',
#     u'mag': 2.66,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 28,
#     u'place': u'Central California',
#     u'rms': 0.06,
#     u'sig': 109,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157469970160,
#     u'title': u'M 2.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756508716,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022381'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.0003333, 39.9808333, 3.061],
#     u'type': u'Point'},
#    u'id': u'nc1022380',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022380',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022380&format=geojson',
#     u'dmin': 0.5018,
#     u'felt': None,
#     u'gap': 324,
#     u'ids': u',nc1022380,',
#     u'mag': 2.8,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 3,
#     u'place': u'Northern California',
#     u'rms': 0.05,
#     u'sig': 121,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157463546970,
#     u'title': u'M 2.8 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756501340,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022380'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.259, 34.1688333, 6], u'type': u'Point'},
#    u'id': u'ci3317607',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3317607',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3317607&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': 277,
#     u'ids': u',ci3317607,',
#     u'mag': 2.8,
#     u'magType': u'mh',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 10,
#     u'place': u'18km NNE of San Miguel Is., CA',
#     u'rms': 0.37,
#     u'sig': 121,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157378724000,
#     u'title': u'M 2.8 - 18km NNE of San Miguel Is., CA',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031473070,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3317607'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.4268333, 40.8028333, 29.394],
#     u'type': u'Point'},
#    u'id': u'nc1022376',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022376',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022376&format=geojson',
#     u'dmin': 0.2423,
#     u'felt': None,
#     u'gap': 270,
#     u'ids': u',nc1022376,',
#     u'mag': 3.9,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 12,
#     u'place': u'Northern California',
#     u'rms': 0.11,
#     u'sig': 234,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157378331510,
#     u'title': u'M 3.9 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756496284,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022376'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4725, 36.9101667, 4.856],
#     u'type': u'Point'},
#    u'id': u'nc1022375',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022375',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022375&format=geojson',
#     u'dmin': 0.03514,
#     u'felt': None,
#     u'gap': 51,
#     u'ids': u',nc1022375,',
#     u'mag': 3.44,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 47,
#     u'place': u'Central California',
#     u'rms': 0.14,
#     u'sig': 182,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157362301270,
#     u'title': u'M 3.4 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756490370,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022375'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-115.9993333, 36.9261667, 6],
#     u'type': u'Point'},
#    u'id': u'ci3317606',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3317606',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3317606&format=geojson',
#     u'dmin': 1.7,
#     u'felt': None,
#     u'gap': 288,
#     u'ids': u',ci3317606,',
#     u'mag': 3.25,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 5,
#     u'place': u'67km E of Beatty, NV',
#     u'rms': 0.66,
#     u'sig': 162,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157351785260,
#     u'title': u'M 3.3 - 67km E of Beatty, NV',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031197090,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3317606'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.3201667, 32.015, 6], u'type': u'Point'},
#    u'id': u'ci3317605',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3317605',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3317605&format=geojson',
#     u'dmin': 0.6579,
#     u'felt': None,
#     u'gap': 274,
#     u'ids': u',ci3317605,',
#     u'mag': 2.64,
#     u'magType': u'mh',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 5,
#     u'place': u'33km ENE of Ensenada, B.C., MX',
#     u'rms': 0.57,
#     u'sig': 107,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157347798170,
#     u'title': u'M 2.6 - 33km ENE of Ensenada, B.C., MX',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031766320,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3317605'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4635, 36.927, 4.046],
#     u'type': u'Point'},
#    u'id': u'nc1022372',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022372',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022372&format=geojson',
#     u'dmin': 0.04234,
#     u'felt': None,
#     u'gap': 61,
#     u'ids': u',nc1022372,',
#     u'mag': 2.72,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 26,
#     u'place': u'Central California',
#     u'rms': 0.12,
#     u'sig': 114,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157333236920,
#     u'title': u'M 2.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756469611,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022372'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.47, 36.916, 6.096], u'type': u'Point'},
#    u'id': u'nc1022368',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022368',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022368&format=geojson',
#     u'dmin': 0.03604,
#     u'felt': None,
#     u'gap': 46,
#     u'ids': u',nc1022368,',
#     u'mag': 2.88,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 78,
#     u'place': u'Central California',
#     u'rms': 0.11,
#     u'sig': 128,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157298171680,
#     u'title': u'M 2.9 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756449030,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022368'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.1193333, 36.5315, 9.488],
#     u'type': u'Point'},
#    u'id': u'nc1022364',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022364',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022364&format=geojson',
#     u'dmin': 0.01982,
#     u'felt': None,
#     u'gap': 58,
#     u'ids': u',nc1022364,',
#     u'mag': 2.76,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 38,
#     u'place': u'Central California',
#     u'rms': 0.04,
#     u'sig': 117,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157286609500,
#     u'title': u'M 2.8 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756417940,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022364'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.654, 36.5013333, 14.278],
#     u'type': u'Point'},
#    u'id': u'nc1022362',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022362',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022362&format=geojson',
#     u'dmin': 0.1847,
#     u'felt': None,
#     u'gap': 224,
#     u'ids': u',nc1022362,',
#     u'mag': 3.78,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 18,
#     u'place': u'Central California',
#     u'rms': 0.06,
#     u'sig': 220,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157268865970,
#     u'title': u'M 3.8 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756411201,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022362'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.0335, 36.5596667, 9.35],
#     u'type': u'Point'},
#    u'id': u'nc1022361',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022361',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022361&format=geojson',
#     u'dmin': 0.03243,
#     u'felt': None,
#     u'gap': 100,
#     u'ids': u',nc1022361,',
#     u'mag': 2.73,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 16,
#     u'place': u'Central California',
#     u'rms': 0.04,
#     u'sig': 115,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157267657850,
#     u'title': u'M 2.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756405143,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022361'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-118.5543333, 35.4091667, 0.19],
#     u'type': u'Point'},
#    u'id': u'ci3317602',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3317602',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3317602&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': 140,
#     u'ids': u',ci3317602,',
#     u'mag': 2.78,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 11,
#     u'place': u'21km SSW of Bodfish, CA',
#     u'rms': 0.6,
#     u'sig': 119,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157253936650,
#     u'title': u'M 2.8 - 21km SSW of Bodfish, CA',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454030613750,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3317602'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4695, 36.9148333, 4.514],
#     u'type': u'Point'},
#    u'id': u'nc1022358',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022358',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022358&format=geojson',
#     u'dmin': 0.03694,
#     u'felt': None,
#     u'gap': 98,
#     u'ids': u',nc1022358,',
#     u'mag': 3.04,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 20,
#     u'place': u'Central California',
#     u'rms': 0.07,
#     u'sig': 142,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157242120710,
#     u'title': u'M 3.0 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756392794,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022358'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.1418333, 37.1445, 5.697],
#     u'type': u'Point'},
#    u'id': u'nc1022354',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022354',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022354&format=geojson',
#     u'dmin': 0.09369,
#     u'felt': None,
#     u'gap': 195,
#     u'ids': u',nc1022354,',
#     u'mag': 3.12,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 38,
#     u'place': u'Central California',
#     u'rms': 0.08,
#     u'sig': 150,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157195574720,
#     u'title': u'M 3.1 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756380807,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022354'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-115.1913333, 32.3958333, 15],
#     u'type': u'Point'},
#    u'id': u'ci3317599',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3317599',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3317599&format=geojson',
#     u'dmin': 0.365,
#     u'felt': None,
#     u'gap': 215,
#     u'ids': u',ci3317599,',
#     u'mag': 2.83,
#     u'magType': u'mh',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 7,
#     u'place': u'4km N of Delta, B.C., MX',
#     u'rms': 0.43,
#     u'sig': 123,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 157192287160,
#     u'title': u'M 2.8 - 4km N of Delta, B.C., MX',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031472090,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3317599'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-124.213, 40.3765, 6.184],
#     u'type': u'Point'},
#    u'id': u'nc1022351',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022351',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022351&format=geojson',
#     u'dmin': 0.05946,
#     u'felt': None,
#     u'gap': 204,
#     u'ids': u',nc1022351,',
#     u'mag': 2.51,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 14,
#     u'place': u'Northern California',
#     u'rms': 0.06,
#     u'sig': 97,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157184097790,
#     u'title': u'M 2.5 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756369016,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022351'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4741667, 36.9088333, 3.816],
#     u'type': u'Point'},
#    u'id': u'nc1022350',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022350',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022350&format=geojson',
#     u'dmin': 0.03423,
#     u'felt': None,
#     u'gap': 55,
#     u'ids': u',nc1022350,',
#     u'mag': 2.71,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 22,
#     u'place': u'Central California',
#     u'rms': 0.1,
#     u'sig': 113,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157176161130,
#     u'title': u'M 2.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756365188,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022350'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.462, 36.928, 4.456], u'type': u'Point'},
#    u'id': u'nc1022349',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022349',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022349&format=geojson',
#     u'dmin': 0.04324,
#     u'felt': None,
#     u'gap': 62,
#     u'ids': u',nc1022349,',
#     u'mag': 3.11,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 29,
#     u'place': u'Central California',
#     u'rms': 0.1,
#     u'sig': 149,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157176076490,
#     u'title': u'M 3.1 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756360080,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022349'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-122.8046667, 38.8025, 4.148],
#     u'type': u'Point'},
#    u'id': u'nc1022347',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022347',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022347&format=geojson',
#     u'dmin': 0.0973,
#     u'felt': None,
#     u'gap': 116,
#     u'ids': u',nc1022347,',
#     u'mag': 3.21,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 12,
#     u'place': u'Northern California',
#     u'rms': 0.02,
#     u'sig': 159,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157159301910,
#     u'title': u'M 3.2 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756351217,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022347'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.6218333, 35.893, 7.837],
#     u'type': u'Point'},
#    u'id': u'nc1022345',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022345',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022345&format=geojson',
#     u'dmin': 0.1847,
#     u'felt': None,
#     u'gap': 287,
#     u'ids': u',nc1022345,',
#     u'mag': 2.54,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 34,
#     u'place': u'offshore Central California',
#     u'rms': 0.1,
#     u'sig': 99,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157132570940,
#     u'title': u'M 2.5 - offshore Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756343463,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022345'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4735, 36.9153333, 8.294],
#     u'type': u'Point'},
#    u'id': u'nc1022338',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022338',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022338&format=geojson',
#     u'dmin': 0.07928,
#     u'felt': None,
#     u'gap': 57,
#     u'ids': u',nc1022338,',
#     u'mag': 2.69,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 22,
#     u'place': u'Central California',
#     u'rms': 0.07,
#     u'sig': 111,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157087613640,
#     u'title': u'M 2.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756325617,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022338'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.3531667, 33.9656667, 5.49],
#     u'type': u'Point'},
#    u'id': u'ci3317597',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3317597',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3317597&format=geojson',
#     u'dmin': 0.2883,
#     u'felt': None,
#     u'gap': 75,
#     u'ids': u',usp000097j,ci3317597,',
#     u'mag': 3.15,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 12,
#     u'place': u'14km E of Desert Hot Springs, CA',
#     u'rms': 0.42,
#     u'sig': 153,
#     u'sources': u',us,ci,',
#     u'status': u'reviewed',
#     u'time': 157063901220,
#     u'title': u'M 3.2 - 14km E of Desert Hot Springs, CA',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031765340,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3317597'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-124.7586667, 41.1356667, 3.874],
#     u'type': u'Point'},
#    u'id': u'nc1022335',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022335',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022335&format=geojson',
#     u'dmin': 0.5919,
#     u'felt': None,
#     u'gap': 319,
#     u'ids': u',nc1022335,',
#     u'mag': 3.67,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 8,
#     u'place': u'offshore Northern California',
#     u'rms': 0.07,
#     u'sig': 207,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157050987640,
#     u'title': u'M 3.7 - offshore Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756312577,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022335'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.9788333, 36.4006667, 4.768],
#     u'type': u'Point'},
#    u'id': u'nc1022334',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022334',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022334&format=geojson',
#     u'dmin': 0.04054,
#     u'felt': None,
#     u'gap': 73,
#     u'ids': u',nc1022334,',
#     u'mag': 2.5,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 15,
#     u'place': u'Central California',
#     u'rms': 0.05,
#     u'sig': 96,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157041883140,
#     u'title': u'M 2.5 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756308539,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022334'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.7331667, 40.0356667, 16.314],
#     u'type': u'Point'},
#    u'id': u'nc1022333',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022333',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022333&format=geojson',
#     u'dmin': 0.3784,
#     u'felt': None,
#     u'gap': 313,
#     u'ids': u',nc1022333,',
#     u'mag': 2.62,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 7,
#     u'place': u'Northern California',
#     u'rms': 0.03,
#     u'sig': 106,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 157036912510,
#     u'title': u'M 2.6 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756304483,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022333'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4736667, 36.9113333, 4.606],
#     u'type': u'Point'},
#    u'id': u'nc1022331',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022331',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022331&format=geojson',
#     u'dmin': 0.03423,
#     u'felt': None,
#     u'gap': 55,
#     u'ids': u',nc1022331,',
#     u'mag': 3.4,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 43,
#     u'place': u'Central California',
#     u'rms': 0.14,
#     u'sig': 178,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156991236270,
#     u'title': u'M 3.4 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756294600,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022331'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4746667, 36.911, 4.316],
#     u'type': u'Point'},
#    u'id': u'nc1022330',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022330',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022330&format=geojson',
#     u'dmin': 0.03333,
#     u'felt': None,
#     u'gap': 55,
#     u'ids': u',nc1022330,',
#     u'mag': 3.26,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 28,
#     u'place': u'Central California',
#     u'rms': 0.11,
#     u'sig': 164,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156985436790,
#     u'title': u'M 3.3 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756287614,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022330'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-123.5446667, 41.011, 26.524],
#     u'type': u'Point'},
#    u'id': u'nc1022328',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022328',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022328&format=geojson',
#     u'dmin': 0.1964,
#     u'felt': None,
#     u'gap': 285,
#     u'ids': u',nc1022328,',
#     u'mag': 2.63,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 7,
#     u'place': u'Northern California',
#     u'rms': 0.07,
#     u'sig': 106,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156958605800,
#     u'title': u'M 2.6 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756279558,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022328'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.0783333, 36.5566667, 10.456],
#     u'type': u'Point'},
#    u'id': u'nc1022325',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022325',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022325&format=geojson',
#     u'dmin': 0.04685,
#     u'felt': None,
#     u'gap': 66,
#     u'ids': u',nc1022325,',
#     u'mag': 2.75,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 44,
#     u'place': u'Central California',
#     u'rms': 0.07,
#     u'sig': 116,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156906068160,
#     u'title': u'M 2.8 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756266360,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022325'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.0405, 36.465, 5.353],
#     u'type': u'Point'},
#    u'id': u'nc1022323',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022323',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022323&format=geojson',
#     u'dmin': 0.04414,
#     u'felt': None,
#     u'gap': 72,
#     u'ids': u',nc1022323,',
#     u'mag': 2.97,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 19,
#     u'place': u'Central California',
#     u'rms': 0.05,
#     u'sig': 136,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156883508020,
#     u'title': u'M 3.0 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756254275,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022323'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.0521667, 36.4748333, 5.865],
#     u'type': u'Point'},
#    u'id': u'nc1022322',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022322',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022322&format=geojson',
#     u'dmin': 0.03964,
#     u'felt': None,
#     u'gap': 71,
#     u'ids': u',nc1022322,',
#     u'mag': 2.97,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 38,
#     u'place': u'Central California',
#     u'rms': 0.08,
#     u'sig': 136,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156873680660,
#     u'title': u'M 3.0 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756249140,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022322'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-125.0635, 41.256, 4.785],
#     u'type': u'Point'},
#    u'id': u'nc1022321',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022321',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022321&format=geojson',
#     u'dmin': 0.8387,
#     u'felt': None,
#     u'gap': 317,
#     u'ids': u',nc1022321,',
#     u'mag': 2.82,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 10,
#     u'place': u'offshore Northern California',
#     u'rms': 0.08,
#     u'sig': 122,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156864838250,
#     u'title': u'M 2.8 - offshore Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756240993,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022321'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.013, 36.4466667, -0.592],
#     u'type': u'Point'},
#    u'id': u'nc1022320',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022320',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022320&format=geojson',
#     u'dmin': 0.02252,
#     u'felt': None,
#     u'gap': 76,
#     u'ids': u',nc1022320,',
#     u'mag': 2.75,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 7,
#     u'place': u'Central California',
#     u'rms': 0.11,
#     u'sig': 116,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156859168420,
#     u'title': u'M 2.8 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756237176,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022320'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.6346667, 36.9803333, 4.479],
#     u'type': u'Point'},
#    u'id': u'nc1022319',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022319',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022319&format=geojson',
#     u'dmin': 0.04685,
#     u'felt': None,
#     u'gap': 40,
#     u'ids': u',nc1022319,',
#     u'mag': 3.46,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 55,
#     u'place': u'Northern California',
#     u'rms': 0.08,
#     u'sig': 184,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156852708350,
#     u'title': u'M 3.5 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756232050,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022319'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.0528333, 36.4771667, 4.951],
#     u'type': u'Point'},
#    u'id': u'nc1022318',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022318',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022318&format=geojson',
#     u'dmin': 0.03784,
#     u'felt': None,
#     u'gap': 108,
#     u'ids': u',nc1022318,',
#     u'mag': 2.57,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 12,
#     u'place': u'Central California',
#     u'rms': 0.03,
#     u'sig': 102,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156843933950,
#     u'title': u'M 2.6 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756225916,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022318'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.2525, 36.6378333, 5.927],
#     u'type': u'Point'},
#    u'id': u'nc1022316',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022316',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022316&format=geojson',
#     u'dmin': 0.01622,
#     u'felt': None,
#     u'gap': 51,
#     u'ids': u',nc1022316,',
#     u'mag': 2.59,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 15,
#     u'place': u'Central California',
#     u'rms': 0.04,
#     u'sig': 103,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156811429040,
#     u'title': u'M 2.6 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756217895,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022316'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4758333, 36.9048333, 5.496],
#     u'type': u'Point'},
#    u'id': u'nc1022313',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022313',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022313&format=geojson',
#     u'dmin': 0.03423,
#     u'felt': None,
#     u'gap': 62,
#     u'ids': u',nc1022313,',
#     u'mag': 2.97,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 26,
#     u'place': u'Central California',
#     u'rms': 0.13,
#     u'sig': 136,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156771107700,
#     u'title': u'M 3.0 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756206514,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022313'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4676667, 36.9305, 2.926],
#     u'type': u'Point'},
#    u'id': u'nc1022312',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022312',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022312&format=geojson',
#     u'dmin': 0.03964,
#     u'felt': None,
#     u'gap': 56,
#     u'ids': u',nc1022312,',
#     u'mag': 3.26,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 33,
#     u'place': u'Central California',
#     u'rms': 0.13,
#     u'sig': 164,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156768939620,
#     u'title': u'M 3.3 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756202583,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022312'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.169, 36.575, 6.425], u'type': u'Point'},
#    u'id': u'nc1022309',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022309',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022309&format=geojson',
#     u'dmin': 0.01351,
#     u'felt': None,
#     u'gap': 44,
#     u'ids': u',nc1022309,',
#     u'mag': 3.17,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 56,
#     u'place': u'Central California',
#     u'rms': 0.04,
#     u'sig': 155,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156740902370,
#     u'title': u'M 3.2 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756193250,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022309'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-111.88, 33.86, 4], u'type': u'Point'},
#    u'id': u'usp000096b',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'p000096b',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000096b&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': None,
#     u'ids': u',usp000096b,',
#     u'mag': 2.5,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'Arizona',
#     u'rms': None,
#     u'sig': 96,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 156740470400,
#     u'title': u'M 2.5 - Arizona',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,',
#     u'tz': None,
#     u'updated': 1415316087910,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000096b'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.464, 36.9226667, 5.926],
#     u'type': u'Point'},
#    u'id': u'nc1022305',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1022305',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1022305&format=geojson',
#     u'dmin': 0.04144,
#     u'felt': None,
#     u'gap': 46,
#     u'ids': u',nc1022305,',
#     u'mag': 2.77,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 72,
#     u'place': u'Central California',
#     u'rms': 0.13,
#     u'sig': 118,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 156689381000,
#     u'title': u'M 2.8 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481756173910,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1022305'},
# ...
#     u'type': u'Point'},
#    u'id': u'nc1020211',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020211',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020211&format=geojson',
#     u'dmin': 0.03063,
#     u'felt': None,
#     u'gap': 60,
#     u'ids': u',nc1020211,',
#     u'mag': 3.03,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 34,
#     u'place': u'Northern California',
#     u'rms': 0.08,
#     u'sig': 141,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142385504980,
#     u'title': u'M 3.0 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746442240,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020211'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.6161667, 36.03, -0.302],
#     u'type': u'Point'},
#    u'id': u'nc1020209',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020209',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020209&format=geojson',
#     u'dmin': 0.1432,
#     u'felt': None,
#     u'gap': 115,
#     u'ids': u',nc1020209,',
#     u'mag': 2.71,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 14,
#     u'place': u'Central California',
#     u'rms': 0.15,
#     u'sig': 113,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142379704650,
#     u'title': u'M 2.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746428158,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020209'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-127.948, 40.276, 28], u'type': u'Point'},
#    u'id': u'usp000070u',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'p000070u',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000070u&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': None,
#     u'ids': u',usp000070u,',
#     u'mag': 3.8,
#     u'magType': u'mb',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'off the coast of Northern California',
#     u'rms': None,
#     u'sig': 222,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 142346486300,
#     u'title': u'M 3.8 - off the coast of Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,',
#     u'tz': None,
#     u'updated': 1415316085075,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000070u'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.8705, 36.617, 5.081],
#     u'type': u'Point'},
#    u'id': u'nc1020203',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020203',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020203&format=geojson',
#     u'dmin': 0.07748,
#     u'felt': None,
#     u'gap': 117,
#     u'ids': u',nc1020203,',
#     u'mag': 2.89,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 17,
#     u'place': u'Central California',
#     u'rms': 0.07,
#     u'sig': 128,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142339303110,
#     u'title': u'M 2.9 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746396172,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020203'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-119.67, 38.765, 5], u'type': u'Point'},
#    u'id': u'usp000070p',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'p000070p',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=usp000070p&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': None,
#     u'ids': u',usp000070p,',
#     u'mag': 3.7,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'us',
#     u'nst': None,
#     u'place': u'Northern California',
#     u'rms': None,
#     u'sig': 211,
#     u'sources': u',us,',
#     u'status': u'reviewed',
#     u'time': 142323041800,
#     u'title': u'M 3.7 - Northern California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,',
#     u'tz': None,
#     u'updated': 1415316085069,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/usp000070p'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.4698333, 36.9146667, 4.616],
#     u'type': u'Point'},
#    u'id': u'nc1020201',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020201',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020201&format=geojson',
#     u'dmin': 0.03694,
#     u'felt': None,
#     u'gap': 57,
#     u'ids': u',nc1020201,',
#     u'mag': 2.55,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 21,
#     u'place': u'Central California',
#     u'rms': 0.11,
#     u'sig': 100,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142320093470,
#     u'title': u'M 2.6 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746385459,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020201'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.1595, 36.5636667, 3.002],
#     u'type': u'Point'},
#    u'id': u'nc1020200',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020200',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020200&format=geojson',
#     u'dmin': 0.00991,
#     u'felt': None,
#     u'gap': 49,
#     u'ids': u',nc1020200,',
#     u'mag': 2.96,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 68,
#     u'place': u'Central California',
#     u'rms': 0.06,
#     u'sig': 135,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142315520300,
#     u'title': u'M 3.0 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746380020,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020200'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.1535, 36.5663333, 3.614],
#     u'type': u'Point'},
#    u'id': u'nc1020199',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020199',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020199&format=geojson',
#     u'dmin': 0.03063,
#     u'felt': None,
#     u'gap': 55,
#     u'ids': u',nc1020199,usp000070n,',
#     u'mag': 3.2,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 41,
#     u'place': u'Central California',
#     u'rms': 0.06,
#     u'sig': 158,
#     u'sources': u',nc,us,',
#     u'status': u'reviewed',
#     u'time': 142315435820,
#     u'title': u'M 3.2 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746365970,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020199'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.7246667, 37.3593333, 6.333],
#     u'type': u'Point'},
#    u'id': u'nc1020195',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020195',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020195&format=geojson',
#     u'dmin': 0.02613,
#     u'felt': None,
#     u'gap': 78,
#     u'ids': u',nc1020195,',
#     u'mag': 2.73,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 23,
#     u'place': u'San Francisco Bay area, California',
#     u'rms': 0.04,
#     u'sig': 115,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142297313880,
#     u'title': u'M 2.7 - San Francisco Bay area, California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746355237,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020195'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.148, 36.5568333, 6.433],
#     u'type': u'Point'},
#    u'id': u'nc1020193',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020193',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020193&format=geojson',
#     u'dmin': 0.03874,
#     u'felt': None,
#     u'gap': 56,
#     u'ids': u',nc1020193,',
#     u'mag': 2.89,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 21,
#     u'place': u'Central California',
#     u'rms': 0.05,
#     u'sig': 128,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142292404080,
#     u'title': u'M 2.9 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746346762,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020193'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.8138333, 36.6243333, 6.837],
#     u'type': u'Point'},
#    u'id': u'nc1020189',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020189',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020189&format=geojson',
#     u'dmin': 0.04234,
#     u'felt': None,
#     u'gap': 158,
#     u'ids': u',nc1020189,',
#     u'mag': 3.74,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 16,
#     u'place': u'Central California',
#     u'rms': 0.08,
#     u'sig': 215,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142269576260,
#     u'title': u'M 3.7 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746329323,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020189'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-117.031, 35.9406667, 6], u'type': u'Point'},
#    u'id': u'ci3319119',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3319119',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3319119&format=geojson',
#     u'dmin': None,
#     u'felt': None,
#     u'gap': 195,
#     u'ids': u',usp000070h,ci3319119,',
#     u'mag': 3.12,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 8,
#     u'place': u'37km ENE of Trona, CA',
#     u'rms': 0.64,
#     u'sig': 150,
#     u'sources': u',us,ci,',
#     u'status': u'reviewed',
#     u'time': 142261832840,
#     u'title': u'M 3.1 - 37km ENE of Trona, CA',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454030879040,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3319119'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.116, 36.5321667, 1.961],
#     u'type': u'Point'},
#    u'id': u'nc1020188',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020188',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020188&format=geojson',
#     u'dmin': 0.03964,
#     u'felt': None,
#     u'gap': 79,
#     u'ids': u',nc1020188,',
#     u'mag': 2.88,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 16,
#     u'place': u'Central California',
#     u'rms': 0.03,
#     u'sig': 128,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142217532830,
#     u'title': u'M 2.9 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746324743,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020188'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.151, 36.5745, 8.574],
#     u'type': u'Point'},
#    u'id': u'nc1020186',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020186',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020186&format=geojson',
#     u'dmin': 0.03153,
#     u'felt': None,
#     u'gap': 55,
#     u'ids': u',nc1020186,',
#     u'mag': 3.1,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 22,
#     u'place': u'Central California',
#     u'rms': 0.03,
#     u'sig': 148,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142179914480,
#     u'title': u'M 3.1 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746316645,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020186'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-120.9888333, 36.4125, 4.831],
#     u'type': u'Point'},
#    u'id': u'nc1020184',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020184',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020184&format=geojson',
#     u'dmin': 0.02703,
#     u'felt': None,
#     u'gap': 74,
#     u'ids': u',nc1020184,',
#     u'mag': 2.6,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 17,
#     u'place': u'Central California',
#     u'rms': 0.05,
#     u'sig': 104,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142170096040,
#     u'title': u'M 2.6 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746308448,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020184'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-116.1896667, 31.9355, 6],
#     u'type': u'Point'},
#    u'id': u'ci3318074',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'3318074',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci3318074&format=geojson',
#     u'dmin': 0.7158,
#     u'felt': None,
#     u'gap': 277,
#     u'ids': u',ci3318074,',
#     u'mag': 3.02,
#     u'magType': u'ml',
#     u'mmi': None,
#     u'net': u'ci',
#     u'nst': 4,
#     u'place': u'41km E of Ensenada, B.C., MX',
#     u'rms': 0.33,
#     u'sig': 140,
#     u'sources': u',ci,',
#     u'status': u'reviewed',
#     u'time': 142150903880,
#     u'title': u'M 3.0 - 41km E of Ensenada, B.C., MX',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',origin,phase-data,',
#     u'tz': None,
#     u'updated': 1454031449000,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/ci3318074'},
#    u'type': u'Feature'},
#   {u'geometry': {u'coordinates': [-121.3065, 36.6813333, 3.743],
#     u'type': u'Point'},
#    u'id': u'nc1020178',
#    u'properties': {u'alert': None,
#     u'cdi': None,
#     u'code': u'1020178',
#     u'detail': u'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc1020178&format=geojson',
#     u'dmin': 0.03063,
#     u'felt': None,
#     u'gap': 40,
#     u'ids': u',nc1020178,',
#     u'mag': 3.16,
#     u'magType': u'md',
#     u'mmi': None,
#     u'net': u'nc',
#     u'nst': 34,
#     u'place': u'Central California',
#     u'rms': 0.07,
#     u'sig': 154,
#     u'sources': u',nc,',
#     u'status': u'reviewed',
#     u'time': 142148682470,
#     u'title': u'M 3.2 - Central California',
#     u'tsunami': 0,
#     u'type': u'earthquake',
#     u'types': u',focal-mechanism,nearby-cities,origin,phase-data,',
#     u'tz': None,
#     u'updated': 1481746285730,
#     u'url': u'https://earthquake.usgs.gov/earthquakes/eventpage/nc1020178'},
#    u'type': u'Feature'},
#   ...],
#  u'metadata': {u'api': u'1.5.8',
#   u'count': 4010,
#   u'generated': 1502742911000,
#   u'status': 200,
#   u'title': u'USGS Earthquakes',
#   u'url': u'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=1970-01-01&endtime=1974-12-31%20&minlatitude=25&maxlatitude=49&minlongitude=-130&maxlongitude=-100&eventtype=earthquake&minmagnitude=2.5'},
#  u'type': u'FeatureCollection'}

# %%
event_list = []
for i in range(json_data['metadata']['count']):
    event_line = []
    event_line.append(json_data['features'][i]['id'])
    event_line += json_data['features'][i]['geometry']['coordinates']
    event_line.append(json_data['features'][i]['properties']['alert']),
    event_line.append(json_data['features'][i]['properties']['cdi']),
    event_line.append(json_data['features'][i]['properties']['code']),
    event_line.append(json_data['features'][i]['properties']['detail']),
    event_line.append(json_data['features'][i]['properties']['dmin']),
    event_line.append(json_data['features'][i]['properties']['felt']),
    event_line.append(json_data['features'][i]['properties']['gap']),
    event_line.append(json_data['features'][i]['properties']['ids'][1:-1]),
    event_line.append(json_data['features'][i]['properties']['mag']),
    event_line.append(json_data['features'][i]['properties']['magType']),
    event_line.append(json_data['features'][i]['properties']['mmi']),
    event_line.append(json_data['features'][i]['properties']['net']),
    event_line.append(json_data['features'][i]['properties']['nst']),
    event_line.append(json_data['features'][i]['properties']['place']),
    event_line.append(json_data['features'][i]['properties']['rms']),
    event_line.append(json_data['features'][i]['properties']['sig']),
    event_line.append(json_data['features'][i]['properties']['sources']),
    event_line.append(json_data['features'][i]['properties']['status']),
    event_line.append(json_data['features'][i]['properties']['time']),
    event_line.append(json_data['features'][i]['properties']['title']),
    event_line.append(json_data['features'][i]['properties']['tsunami']),
    event_line.append(json_data['features'][i]['properties']['type']),
    event_line.append(json_data['features'][i]['properties']['types'][1:-1]),
    event_line.append(json_data['features'][i]['properties']['tz']),
    event_line.append(json_data['features'][i]['properties']['updated']),
    event_line.append(json_data['features'][i]['properties']['url']),

    event_list.append(event_line)

# %%
cols = ['id', 'lat', 'long', 'depth', 'alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', \
        'mag', 'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources', 'status', 'time', \
        'title', 'tsunami', 'type', 'types', 'tz', 'updated', 'url']
quakes = pd.DataFrame(event_list, columns = cols)

# %%
quakes.shape
# Out:
# (4010, 30)

# %%
quakes.to_csv("./US-west-half_1Q70-4Q74.csv", index=False),
# Out:
# (None,)

# %%
quakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13866 entries, 0 to 13865
# Data columns (total 30 columns):
# id         13866 non-null object
# lat        13866 non-null float64
# long       13866 non-null float64
# depth      13866 non-null float64
# alert      0 non-null object
# cdi        4 non-null float64
# code       13866 non-null object
# detail     13866 non-null object
# dmin       5561 non-null float64
# felt       4 non-null float64
# gap        12669 non-null float64
# ids        13866 non-null object
# mag        13866 non-null float64
# magType    13866 non-null object
# mmi        21 non-null float64
# net        13866 non-null object
# nst        12669 non-null float64
# place      13866 non-null object
# rms        13549 non-null float64
# sig        13866 non-null int64
# sources    13866 non-null object
# status     13866 non-null object
# time       13866 non-null int64
# title      13866 non-null object
# tsunami    13866 non-null int64
# type       13866 non-null object
# types      13866 non-null object
# tz         7 non-null float64
# updated    13866 non-null int64
# url        13866 non-null object
# dtypes: float64(12), int64(4), object(14)
# memory usage: 3.2+ MB

# %% [markdown]
# ## Download complete - now to examine and clean it.
#
# After downloading the separate files for east and west coast, and for smaller year spans,  I recombined everything into one US-quake.csv file, 45MB in size.  This can be loaded and used as the dataset for this capstone project

# %%
import pandas as pd

df = pd.read_csv('US-quake.csv')
df.shape
# Out:
# (114503, 30)

# %%
df.head(3)
# Out:
#           id         lat       long  depth alert  cdi     code  \
# 0  nc1022389 -121.873500  36.593000  4.946   NaN  NaN  1022389
# 1  nc1022388 -121.464500  36.929000  3.946   NaN  NaN  1022388
# 2  ci3319041 -116.128833  29.907667  6.000   NaN  NaN  3319041
#
#                                               detail     dmin  felt  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.03694   NaN
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.04144   NaN
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...  2.73400   NaN
#
#                          ...                          sources    status  \
# 0                        ...                             ,nc,  reviewed
# 1                        ...                             ,nc,  reviewed
# 2                        ...                             ,ci,  reviewed
#
#            time                                     title  tsunami  \
# 0  1.576600e+11                M 3.4 - Central California        0
# 1  1.576470e+11                M 3.0 - Central California        0
# 2  1.576410e+11  M 4.6 - 206km SSE of Maneadero, B.C., MX        0
#
#          type                                            types  tz  \
# 0  earthquake  focal-mechanism,nearby-cities,origin,phase-data NaN
# 1  earthquake                  nearby-cities,origin,phase-data NaN
# 2  earthquake                                origin,phase-data NaN
#
#         updated                                                url
# 0  1.481760e+12  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1.481760e+12  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1.454030e+12  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [3 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114503 entries, 0 to 114502
# Data columns (total 30 columns):
# id         114503 non-null object
# lat        114503 non-null float64
# long       114503 non-null float64
# depth      114498 non-null float64
# alert      693 non-null object
# cdi        14130 non-null float64
# code       114503 non-null object
# detail     114503 non-null object
# dmin       68118 non-null float64
# felt       14130 non-null float64
# gap        105961 non-null float64
# ids        114503 non-null object
# mag        114503 non-null float64
# magType    114417 non-null object
# mmi        2955 non-null float64
# net        114503 non-null object
# nst        98355 non-null float64
# place      114503 non-null object
# rms        108641 non-null float64
# sig        114503 non-null int64
# sources    114503 non-null object
# status     114503 non-null object
# time       114503 non-null float64
# title      114503 non-null object
# tsunami    114503 non-null int64
# type       114503 non-null object
# types      114503 non-null object
# tz         17198 non-null float64
# updated    114503 non-null float64
# url        114503 non-null object
# dtypes: float64(14), int64(2), object(14)
# memory usage: 26.2+ MB

# %% [markdown]
# ## Discussion
#
# Everything is currently text, and there is missing data.   This is expected, as not all information is recorded for every quake.
#
# A data dictionary describing this data is availabe at https://earthquake.usgs.gov/data/comcat/data-eventterms.php
#
# Of most importance to this project will be **time, lat, long, depth, magnitude, mmi** and **cdi.**
#
# time       114514 non-null object
# id         114514 non-null object
# lat        114514 non-null object
# long       114514 non-null object
# depth      114509 non-null object
# mag        114514 non-null object
# mmi        2966 non-null object
# cdi        14141 non-null object
#
# All but **mmi** and **cdi** are compete.
#
# The Modified Mercali Intensity (mmi) is only computed for quakes that cause damage, and cdi is computed from citizen reports beginning around 2005.  The full dataset will be used to examine any changes in earthquake frequency over time, and the smaller dataset of mmi/cdi will be used to calibrate the cdi intensity data.  With that done, the slighty larger cdi dataset can be used to explore the relationship between magnitude and intensity, and to validate the current formulas, and to develop new, more regionally focused, formulas.
#
# My evolving list of questions to attempt to answer with this data include ...
#
# - have there been any increase or decrease in # of quakes in specific regions?
#    - by depth, by magnitude, by intensity
#    - can we group by state, by zip code, by geologic unit, by fault zone …
#      - need to geocode, and somehow classify geologic characteristics
#    - can it be correlated to human activity, especially fracking or injection (these are separate)
#
# - Are there more discrete regional differences in magnitude/intensity relationship
#
# - Is citizen reported DYFI data, converted to CDI, accurate.  Does it correspond with MMI

# %%
# Continuous Data
#    Convert to float
#       lat, long, depth, cdi, dmin, gap, mag, mmi, rms
df[['lat','long', 'depth', 'cdi', 'dmin', 'gap', 'mag', 'mmi', 'rms']] = \
df[['lat','long', 'depth', 'cdi', 'dmin', 'gap', 'mag', 'mmi', 'rms']].apply(pd.to_numeric, errors='coerce')

#    Convert to int
#       felt, nst, sig, tz(need to learn what this is)
df[['felt', 'nst', 'sig', 'tz']] = df[['felt', 'nst', 'sig', 'tz']].apply(pd.to_numeric, errors='coerce')
# Need to deal with the NaNs before casting as integer 
# df['felt'] = df['felt'].astype(int)
# df['nst'] = df['nst'].astype(int)
# df['sig'] = df['sig'].astype(int)
# df['tz'] = df['tz'].astype(int)

# Convert to boolian 
#   tsunami
df['tsunami'] = df['tsunami'].apply(pd.to_numeric, errors='coerce')
df['tsunami'] = df['tsunami'].astype(bool)

# Convert to date/time  
#           see: https://stackoverflow.com/questions/21787496/converting-epoch-time-with-milliseconds-to-datetime
#           example code given in cell below
#   time, updated

import datetime

df['time'] = df['time'].apply(pd.to_numeric)
df['updated'] = df['updated'].apply(pd.to_numeric)

df['time'] = df['time'].astype(int)
df['updated'] = df['updated'].astype(int)

df['time'] = df['time'].apply(lambda x: datetime.datetime.fromtimestamp(int(x)/1000.0) )
df['updated'] = df['updated'].apply(lambda x: datetime.datetime.fromtimestamp(int(x)/1000.0) )


# Convert to ordinal 
#   alert
#
# This code will convert, but how to handle blanks, which mean no alert issued? 
# Is it OK to make them 0, or does that give some unintended importance?
def ordinize(strval, ordered_list, start_idx, idx_skip):
    i = 0
    for val in ordered_list:
        if strval == val:
            return i*idx_skip + start_idx
        i += 1

df['alert'] = df['alert'].apply(lambda x: ordinize(x, ['green', 'yellow', 'red'], 1, 1))
df['alert'] = df['alert'].fillna(value=0)

# dummy (if used - not sure they will be needed for any of the project goals)
#   magType, net, sources, status

# leave as string (informational and reference only, not needed for model learning or prediction)
#   id, code detail, ids, place, title, type, types, url

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114503 entries, 0 to 114502
# Data columns (total 30 columns):
# id         114503 non-null object
# lat        114503 non-null float64
# long       114503 non-null float64
# depth      114498 non-null float64
# alert      114503 non-null float64
# cdi        14130 non-null float64
# code       114503 non-null object
# detail     114503 non-null object
# dmin       68118 non-null float64
# felt       14130 non-null float64
# gap        105961 non-null float64
# ids        114503 non-null object
# mag        114503 non-null float64
# magType    114417 non-null object
# mmi        2955 non-null float64
# net        114503 non-null object
# nst        98355 non-null float64
# place      114503 non-null object
# rms        108641 non-null float64
# sig        114503 non-null int64
# sources    114503 non-null object
# status     114503 non-null object
# time       114503 non-null datetime64[ns]
# title      114503 non-null object
# tsunami    114503 non-null bool
# type       114503 non-null object
# types      114503 non-null object
# tz         17198 non-null float64
# updated    114503 non-null datetime64[ns]
# url        114503 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(13), int64(1), object(13)
# memory usage: 25.4+ MB

# %%
# Deal with missing values

# Depth: 5 missing - delete these rows
df = df.dropna(subset=['depth'])

# magType: 86 missing,  fill with 'Unknown'  (there is one existing with Unknown)
df['magType'] = df['magType'].fillna(value='Unknown')


# cdi, mmi, felt:  Leave as NaN, analysis of mmi cdi/felt relationship will be done for existing values only
# dmin, gap, nst, rms, tz: Leave as NaN, no planned analysis or modeling uses these features.
# Out:
# /Users/erhepp/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114498 entries, 0 to 114502
# Data columns (total 30 columns):
# id         114498 non-null object
# lat        114498 non-null float64
# long       114498 non-null float64
# depth      114498 non-null float64
# alert      114498 non-null float64
# cdi        14130 non-null float64
# code       114498 non-null object
# detail     114498 non-null object
# dmin       68118 non-null float64
# felt       14130 non-null float64
# gap        105961 non-null float64
# ids        114498 non-null object
# mag        114498 non-null float64
# magType    114498 non-null object
# mmi        2955 non-null float64
# net        114498 non-null object
# nst        98355 non-null float64
# place      114498 non-null object
# rms        108641 non-null float64
# sig        114498 non-null int64
# sources    114498 non-null object
# status     114498 non-null object
# time       114498 non-null datetime64[ns]
# title      114498 non-null object
# tsunami    114498 non-null bool
# type       114498 non-null object
# types      114498 non-null object
# tz         17198 non-null float64
# updated    114498 non-null datetime64[ns]
# url        114498 non-null object
# dtypes: bool(1), datetime64[ns](2), float64(13), int64(1), object(13)
# memory usage: 26.3+ MB

# %%
df.head()
# Out:
#            id         lat       long   depth alert  cdi      code  \
# 0   nc1022389 -121.873500  36.593000   4.946   NaN  NaN   1022389
# 1   nc1022388 -121.464500  36.929000   3.946   NaN  NaN   1022388
# 2   ci3319041 -116.128833  29.907667   6.000   NaN  NaN   3319041
# 3  usp00009ad -116.402000  30.424000  33.000   NaN  NaN  p00009ad
# 4  usp000099y -116.185000  30.757000  33.000   NaN  NaN  p000099y
#
#                                               detail     dmin  felt  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.03694   NaN
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.04144   NaN
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...  2.73400   NaN
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN   NaN
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...      NaN   NaN
#
#                          ...                          sources    status  \
# 0                        ...                             ,nc,  reviewed
# 1                        ...                             ,nc,  reviewed
# 2                        ...                             ,ci,  reviewed
# 3                        ...                             ,us,  reviewed
# 4                        ...                          ,ci,us,  reviewed
#
#            time                                     title  tsunami  \
# 0  157660096830                M 3.4 - Central California    False
# 1  157646814820                M 3.0 - Central California    False
# 2  157641167870  M 4.6 - 206km SSE of Maneadero, B.C., MX    False
# 3  157641135300  M 4.0 - offshore Baja California, Mexico    False
# 4  157550821500  M 4.2 - offshore Baja California, Mexico    False
#
#          type                                            types  tz  \
# 0  earthquake  focal-mechanism,nearby-cities,origin,phase-data NaN
# 1  earthquake                  nearby-cities,origin,phase-data NaN
# 2  earthquake                                origin,phase-data NaN
# 3  earthquake                                           origin NaN
# 4  earthquake                                origin,phase-data NaN
#
#          updated                                                url
# 0  1481756564940  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1481756553974  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1454032083640  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1415316088071  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1454030304990  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 30 columns]

# %%
# Here are the methods for dealing with the two time in milliseconds since the epoch (1970).  I'm leaving times
# In the dataframe, I'm leaving the times as 11 digit integors, and for the moment plan to deal with the 
# conversions when the times are needed for something.  The milliseconds are important in seismology for
# accurate compuation of location and magnitude, it's not clear to me yet whether that will need to be maintained
# for display

import time

ttime = 1481756553974   # example time value for test
s, ms = divmod(ttime, 1000) 
print '{}.{:03d}'.format(time.strftime('%Y-%m-%d %H:%M:%S', time.gmtime(s)), ms)
# Out:
# 2016-12-14 23:02:33.974

# %%
import datetime
import time

ttime = 1481756553974/1000   # example time value for test

print 'ttime:', ttime
print 'fromtimestamp(ttime):', datetime.date.fromtimestamp(ttime)
# Out:
#  ttime: 1481756553
# fromtimestamp(ttime): 2016-12-14

# %%
print 'Now    :', datetime.datetime.now()
print 'Today  :', datetime.datetime.today()
print 'UTC Now:', datetime.datetime.utcnow()

d = datetime.datetime.now()
for attr in [ 'year', 'month', 'day', 'hour', 'minute', 'second', 'microsecond']:
    print attr, ':', getattr(d, attr)
# Out:
#  Now    : 2017-08-20 13:04:44.009927
# Today  : 2017-08-20 13:04:44.010349
# UTC Now: 2017-08-20 17:04:44.010535
# year : 2017
# month : 8
# day : 20
# hour : 13
# minute : 4
# second : 44
# microsecond : 10849

# %%
import datetime
ttime = 1481756553974/float(1000)   # example time value for test
print ttime

dt = datetime.datetime.fromtimestamp(ttime)

for attr in [ 'year', 'month', 'day', 'hour', 'minute', 'second', 'microsecond']:
    print attr, ':', getattr(dt, attr)
# Out:
# 1481756553.97
# 1975-12-14 18:02:33.974000
# year : 2016
# month : 12
# day : 14
# hour : 18
# minute : 2
# second : 33
# microsecond : 974000

# %%
# One of first steps will be to geocode the lat long and find location by township, zipcode, county, state
# I'd also like to tie it to geologic unit or at least some indicator of crustal and surface physical properties
# but this is difficult and I haven't found a suitable reference DB.  ** For the record, this problem has been 
# difficult since the beginning of seismology - knowing the material properties of the rock through which
# the seismic waves travel, and is one reason why we have only east coast and west coast equations for relating
# magnitude and intensity.

# %% [markdown]
# ## EDA
# Visualization of the quake dataset
#  - Map showing location and itensity, maybe interactive , maybe dot size variations for magnitude
#    ( this is like an interactive variant of the standard seismic risk maps )
#      - with a slider bar for year,  # this would show the "bloom" in Oklahoma quakes over last 10 years
#      - and or a slider bar for magnitide
#  - Frequency bar charts per decade (or maybe half decade) divisions, grouped/binned by magnitude, with bars green to red for increasing magnitude
#  - Frequency by depth - still considering if this is useful or interesting
#  - Felt area by magnitide showing geographic differences, maybe just example quakes in various areas
#  - location of reporting agencies/labs with indicator of number of contributions to the dataset
#  - magnitude calculation types by distance of seismograph from epicenter
#  - Scatter plot of relationship between mmi and cdi  intensity assessments, possibly grouped by region

# %% [markdown]
# ## Analysis
# What can be said with statistical signifcance
#  - Hypothesis test of equivalence of mmi and cdi
#  - Hypothesis test of changing quake frequency over time
#  - Hypothesis test of Oklahoma quake magnitude / intensity increasing over time
#  - Characterization of variance in magnitude cacluation methods
#  - Characterization of variance in cdi ?
#  - Characterization of variance among reporting agencies

# %% [markdown]
# ## Modeling
#
#  - Validate existing USGS magnitude / intensity equations for east and west coast
#  - New equations for magnitude and intensity relationship
#  - Not sure about stepping it the EQ prediction morass, but maybe something based on frequency of mag 7 or larger?
#  - Need to generate more ideas here
